# %%
import requests
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import pandas as pd
from google.cloud import bigquery
import os



def get_max_game_date():
    project_id = os.environ.get('GCP_PROJECT')
    client = bigquery.Client(project=project_id)
    
    QUERY = (
    "SELECT date_add(max(game_date), INTERVAL 1 day) as max_game_date FROM `nba.raw_basketballreference_game`"
    )
    query_job = client.query(QUERY)  # API request
    rows = query_job.result()  # Waits for query to finish
    
    for result in rows:
        load_date = result.max_game_date
    
    return load_date

def get_game_players(soup, player_game_data, id_string, game_key, stat_type, h_or_a, team_abbrev, game_date):
    rows = soup.find('table', id=id_string).find('tbody').find_all('tr')
    cnt = 1

    #print(str(rows))
    for player in rows:
        game_players = {}
        game_players['game_key'] = game_key
        game_players['game_date'] = game_date
        game_players['h_or_a'] = h_or_a
        game_players['team_abbrev'] = team_abbrev
        game_players['stat_period'] = stat_type
        game_players['player'] = player.find('th',{"data-stat": "player"}).text
        #print(game_players['player'])
        
        player_node = player.find('th',{"data-stat": "player"})
        
        # Ignore Header Line
        if game_players['player'] != 'Reserves' and player_node.has_attr('data-append-csv'):
        
            a = player.find('th',{"data-stat": "player"}).find('a',href=True)
            if a is not None:
                game_players['player_link'] = a['href']
            else:
                game_players['player_link'] = None
            
            game_players['player_key'] = player_node['data-append-csv']
            game_players['reason'] = get_text(player.find('td',{"data-stat": "reason"}))
            game_players['mp'] = get_text(player.find('td',{"data-stat": "mp"}))
            game_players['fg'] = get_text(player.find('td',{"data-stat": "fg"}))
            game_players['fga'] = get_text(player.find('td',{"data-stat": "fga"}))
            game_players['fg_pct'] = get_text(player.find('td',{"data-stat": "fg_pct"}))
            game_players['fg3'] = get_text(player.find('td',{"data-stat": "fg3"}))
            game_players['fg3a'] = get_text(player.find('td',{"data-stat": "fg3a"}))
            game_players['fg3_pct'] = get_text(player.find('td',{"data-stat": "fg3_pct"}))
            game_players['ft'] = get_text(player.find('td',{"data-stat": "ft"}))
            game_players['fta'] = get_text(player.find('td',{"data-stat": "fta"}))
            game_players['ft_pct'] = get_text(player.find('td',{"data-stat": "ft_pct"}))
            game_players['orb'] = get_text(player.find('td',{"data-stat": "orb"}))
            game_players['drb'] = get_text(player.find('td',{"data-stat": "drb"}))
            game_players['trb'] = get_text(player.find('td',{"data-stat": "trb"}))
            game_players['ast'] = get_text(player.find('td',{"data-stat": "ast"}))
            game_players['stl'] = get_text(player.find('td',{"data-stat": "stl"}))
            game_players['blk'] = get_text(player.find('td',{"data-stat": "blk"}))
            game_players['tov'] = get_text(player.find('td',{"data-stat": "tov"}))
            game_players['pf'] = get_text(player.find('td',{"data-stat": "pf"}))
            game_players['pts'] = get_text(player.find('td',{"data-stat": "pts"}))
            game_players['plus_minus'] = get_text(player.find('td',{"data-stat": "plus_minus"}))
            game_players['player_stat_key'] = game_players['game_key'] + '|' + game_players['player_key'] + '|' + game_players['stat_period'] 
            if cnt <= 5:
                game_players['starter_flag'] = True 
            else:
                game_players['starter_flag'] = False
            game_players['load_datetime'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")  
            #print(game_players)
            player_game_data.append(game_players)
            cnt += 1

    return player_game_data
   
def get_text(stat):
    if stat is not None:
        if stat.text != "":
            txt = stat.text
        else:
            txt = None
    else:
        txt = None
    return txt

def  nba_basketballreference_scraper(request):
    #Get project ID where function is run 
    project_id = os.environ.get('GCP_PROJECT')
    ##########################################################################
    # Input Data Check
    ##########################################################################
    
    # If request has specific StartDate/EndDate use those
    # Otherwise, use the maximum game date in BigQuery as StartDate and Yesterday as EndDate

    try:
        request_json = request
        if request_json and 'StartDate' in request_json:  
            startDate = datetime.strptime(request_json['StartDate'], '%Y-%m-%d').date()            
        else:
            startDate = get_max_game_date()
        if request_json and 'EndDate' in request_json:  
            endDate = datetime.strptime(request_json['EndDate'], '%Y-%m-%d').date() 
        else:
            endDate = (datetime.now() + timedelta(days=-1)).date()
    except Exception as e:
        raise ValueError("Start & End dates must be in YYYY-MM-DD format") from e

    # Distinct list of Months between start and end date
    delta = endDate - startDate       # as timedelta

    if delta.days < 0:
        raise ValueError("Start Date can't be before End Date")
    
    ##########################################################################
    # Get Distinct Months for schedule to scrape
    ##########################################################################
    
    yearmonths = []
    for i in range(delta.days + 1):
        r = {}
        day = startDate + timedelta(days=i)
        r['monthname'] = day.strftime('%B').lower()
        if day.month > 9:
            r['year'] = day.year + 1
        else:
            r['year'] = day.year
        if r not in yearmonths: 
            yearmonths.append(r)
    #print(yearmonths)
    
    ##########################################################################
    # Scrape Schedule
    ##########################################################################
    player_game_rows_loaded = 0
    game_rows_loaded = 0
    
    try:
        schedule = []
        for v in yearmonths:        
            year = str(v['year'])
            month = v['monthname']
            ## the 2019-2020 season had games in October 2019 and 2020 requiring custom URL logic
            if month == 'october' and (year == '2020' or year == '2021'):
                url = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}-{v["year"] - 1}.html'
            else:
                url = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}.html'
            #print(url)
        
            html = requests.get(url)
            
            if html.ok:
                soup = BeautifulSoup(html.content, 'html.parser')  
            else:
                print(f'No data for {month} {year} because enountered error code {html.status_code}')
                continue

            rows = soup.find('table', id="schedule").find('tbody').find_all('tr')
            #print(rows)
            
            for row in rows:
                game_date_node = row.find('th',{"data-stat": "date_game"})
                if game_date_node is not None:

                    game_date = datetime.strptime(game_date_node.text, '%a, %b %d, %Y').date()
                    if game_date >= startDate and game_date <= endDate:
                        #cells = row.find_all(['td', 'th'])
                        r = {}
                        #r.setdefault(game_start_time, []).append(value)

                        v1 = row.find('th',{"data-stat": "date_game"})
                        #r[k1] = v1.text
                        r['game_date'] = datetime.strptime(v1.text, '%a, %b %d, %Y').strftime("%Y-%m-%d")
                        
                        v2 = row.find('td',{"data-stat": "game_start_time"})
                        r['game_start_time'] = v2.text if v2 else None
                        
                        v3 = row.find('td',{"data-stat": "visitor_team_name"})
                        r['visitor_team_name'] = v3.text
                        r['away_abbr'] = v3['csk'].split('.')[0]
                        
                        v4 = row.find('td',{"data-stat": "visitor_pts"})
                        r['visitor_pts'] = v4.text if v4 else None
                        
                        v5 = row.find('td',{"data-stat": "home_team_name"})
                        r['home_team_name'] = v5.text
                        r['home_abbr'] = v5['csk'].split('.')[0]
                        
                        v6 = row.find('td',{"data-stat": "home_pts"})
                        r['home_pts'] = v6.text if v6 else None
                        
                        v7 = row.find('td',{"data-stat": "box_score_text"}).find('a',href=True)
                        r['box_score_url'] = v7['href'] if v7 else None
                            
                        v8 = row.find('td',{"data-stat": "attendance"})
                        r['attendance'] = v8.text if v8 else None
                        
                        v9 = row.find('td',{"data-stat": "overtimes"})
                        r['overtimes'] = v9.text if v9 else None
                        
                        if r['game_start_time']:
                            v12 = r['away_abbr'] + r['game_date'].replace('-','') + r['home_abbr'] + r['game_start_time'].replace(':','')
                        else:
                            v12 = r['away_abbr'] + r['game_date'].replace('-','') + r['home_abbr']
                        r['game_key'] = v12 if v12 else None
                    
                        schedule.append(r)
            #print(schedule)            
        
            ##########################################################################
            # Scrape Games in Schedule
            ##########################################################################
            games_data = []
            player_game_data = []

            for game in schedule:
                if 'box_score_url' in game and game['box_score_url'] != "" and game['box_score_url'] is not None:


                    url = "https://www.basketball-reference.com" + game['box_score_url']

                    #print(url)
                    r = requests.get(url)
 
                    soup = BeautifulSoup(str(r.content).replace("<!--","").replace('-->',''), 'html.parser')

                    ##############################################
                    # Line Score
                    rows = soup.find('table', id="line_score").find_all('tr')

                    # Away Line Score
                    r_num = 1
                    for away in rows[2].find_all('td'):
                        test_strong = away.find('strong') # Strong represents the total score ... ignore
                        if test_strong is None and r_num < 7:
                            k='a_g' + str(r_num) + '_score'
                            game[k] = away.text if away.text != "" else None
                        r_num+=1

                    # Home Line Score
                    r_num = 1
                    for home in rows[3].find_all('td'):
                        test_strong = home.find('strong') # Strong represents the total score ... ignore
                        if test_strong is None and r_num < 7:
                            k='h_g' + str(r_num) + '_score'
                            game[k] = home.text if home.text != "" else None
                        r_num+=1      

                    ##############################################
                    # Four Facts
                    rows = soup.find('table', id="four_factors").find_all('tr')

                    # Away Four Factors
                    game['a_ff_pace'] = rows[2].find('td',{"data-stat": "pace"}).text
                    game['a_ff_efg_pct'] = rows[2].find('td',{"data-stat": "efg_pct"}).text
                    game['a_ff_tov_pct'] = rows[2].find('td',{"data-stat": "tov_pct"}).text
                    game['a_ff_orb_pct'] = rows[2].find('td',{"data-stat": "orb_pct"}).text
                    game['a_ff_ft_rate'] = rows[2].find('td',{"data-stat": "ft_rate"}).text
                    game['a_ff_off_rtg'] = rows[2].find('td',{"data-stat": "off_rtg"}).text

                    # Home Four Factors
                    game['h_ff_pace'] = rows[3].find('td',{"data-stat": "pace"}).text
                    game['h_ff_efg_pct'] = rows[3].find('td',{"data-stat": "efg_pct"}).text
                    game['h_ff_tov_pct'] = rows[3].find('td',{"data-stat": "tov_pct"}).text
                    game['h_ff_orb_pct'] = rows[3].find('td',{"data-stat": "orb_pct"}).text
                    game['h_ff_ft_rate'] = rows[3].find('td',{"data-stat": "ft_rate"}).text
                    game['h_ff_off_rtg'] = rows[3].find('td',{"data-stat": "off_rtg"}).text
                    game['load_datetime'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")        

                    #now = datetime.now() # current date and time
                    #now.strftime("%m/%d/%Y, %H:%M:%S")


                    #player_game_data = []
                    game_date = game['game_date']

                    ##############################################
                    # Game Box - Home
                    stat_type = "game"
                    h_or_a = "h"
                    team_abbrev = game['home_abbr']
                    id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    ##############################################
                    # Game Box - Away
                    stat_type = "game"
                    h_or_a = "a"
                    team_abbrev = game['away_abbr']
                    id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q1 Box - Home
                    # stat_type = "q1"
                    # h_or_a = "h"
                    # team_abbrev = game['home_abbr']
                    # id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q1 Box - Away
                    # stat_type = "q1"
                    # h_or_a = "a"
                    # team_abbrev = game['away_abbr']
                    # id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q2 Box - Home
                    # stat_type = "q2"
                    # h_or_a = "h"
                    # team_abbrev = game['home_abbr']
                    # id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q2 Box - Away
                    # stat_type = "q2"
                    # h_or_a = "a"
                    # team_abbrev = game['away_abbr']
                    # id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q3 Box - Home
                    # stat_type = "q3"
                    # h_or_a = "h"
                    # team_abbrev = game['home_abbr']
                    # id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q3 Box - Away
                    # stat_type = "q3"
                    # h_or_a = "a"
                    # team_abbrev = game['away_abbr']
                    # id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q4 Box - Home
                    # stat_type = "q4"
                    # h_or_a = "h"
                    # team_abbrev = game['home_abbr']
                    # id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q4 Box - Away
                    # stat_type = "q4"
                    # h_or_a = "a"
                    # team_abbrev = game['away_abbr']
                    # id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    games_data.append(game)


            ##########################################################################
            # Check for empty game data
            ##########################################################################
            # Continue to next month if there were no games in the month starting at the start date
            if not games_data:
                continue

            ##########################################################################
            # Save to BigQuery
            ##########################################################################

            # print(player_game_data)
            # print(games_data)
            # Create new bigquery client each loop
            client = bigquery.Client(project=project_id)
            
            print(f'Loading data for {month} {year}')
 
            #Publish game data
            try:
                pandas_games_data = pd.DataFrame(games_data)
                pandas_games_data['game_date'] = pandas_games_data['game_date'].astype('datetime64[ns]').datetime.date
                pandas_games_data['load_datetime'] = pandas_games_data['load_datetime'].astype('datetime64[ns]').dat.date
                job_config = bigquery.LoadJobConfig()
                job_config.autodetect='False'
                job_config.create_disposition = 'CREATE_IF_NEEDED'
                job_config.write_disposition = 'WRITE_APPEND'
                ## Set schema for specific columns where more information is needed (e.g. not NULLABLE or specific date/time)
                job_config.schema = [
                    bigquery.SchemaField('game_key','STRING', 'REQUIRED'),
                    bigquery.SchemaField('game_date','DATE', 'REQUIRED'),
                    bigquery.SchemaField('home_team_name','STRING', 'REQUIRED'),
                    bigquery.SchemaField('home_abbr','STRING', 'REQUIRED'),
                    bigquery.SchemaField('visitor_team_name','STRING', 'REQUIRED'),
                    bigquery.SchemaField('away_abbr','STRING', 'REQUIRED'),
                    bigquery.SchemaField('load_datetime','TIMESTAMP')
                ]
                job_config.time_partitioning = bigquery.TimePartitioning(
                    type_=bigquery.TimePartitioningType.DAY,
                    field="game_date")
                job_game = client.load_table_from_dataframe(pandas_games_data, 'nba.raw_basketballreference_game', job_config=job_config)
                game_result = job_game.result()
                game_message = (
                    f'Job ID: {game_result.job_id} '
                    f'was started {game_result.started} '
                    f'and ended {game_result.ended} '
                    f'loading {game_result.output_rows} row(s) '
                    f'to {game_result.destination}')
                print(game_message)
                game_rows_loaded = game_rows_loaded + game_result.output_rows
            except Exception as e:
                raise ValueError("Game data failed to load. See error and do not load player data") from e

            #Publish player game data
            pandas_player_game_data = pd.DataFrame(player_game_data)
            pandas_player_game_data['game_date'] = pandas_player_game_data['game_date'].astype('datetime64[ns]')
            pandas_player_game_data['load_datetime'] = pandas_player_game_data['load_datetime'].astype('datetime64[ns]')
            job_config = bigquery.LoadJobConfig()
            job_config.autodetect='False'
            job_config.create_disposition = 'CREATE_IF_NEEDED'
            job_config.write_disposition = 'WRITE_APPEND'
             ## Set schema for specific columns where more information is needed (e.g. not NULLABLE or specific date/time)
            job_config.schema = [
                bigquery.SchemaField('player_stat_key','STRING', 'REQUIRED'),
                bigquery.SchemaField('game_date','DATE'),
                bigquery.SchemaField('load_datetime','TIMESTAMP'),
                bigquery.SchemaField('starter_flag','BOOL')
            ]
            job_config.time_partitioning = bigquery.TimePartitioning(
                type_=bigquery.TimePartitioningType.DAY,
                field="game_date")
            job_player = client.load_table_from_dataframe(pandas_player_game_data, 'nba.raw_basketballreference_playerbox', job_config=job_config)
            player_result = job_player.result()
            player_message = (
                f'Job ID: {player_result.job_id} '
                f'was started {player_result.started} '
                f'and ended {player_result.ended} '
                f'loading {player_result.output_rows} row(s) '
                f'to {player_result.destination}')
            print(player_message)
            player_game_rows_loaded = player_game_rows_loaded + player_result.output_rows



    except Exception as e: 
        raise ValueError("Load Job Failed - Check error log for specific details") from e

    return f'Successfully loaded {player_game_rows_loaded} row(s) to raw_basketballreference_playerbox and {game_rows_loaded} to raw_basketballreference_game'

# %%
request = {'StartDate':'1999-07-01', 'EndDate':'2015-07-01'}

# %%
startDate = datetime.strptime(request['StartDate'], '%Y-%m-%d').date()

# %%
endDate = ''

# %%
#Uncomment top row to load up until current time. Use bottom row if setting a manual end date
#endDate_max = (datetime.now() + timedelta(days=-1)).date() 
endDate_max = datetime.strptime(request['EndDate'], '%Y-%m-%d').date()

# %%
while endDate != endDate_max:
    year, month= divmod(startDate.month+1, 12)
    if month == 0: 
          month = 12
          year = year -1
    endDate = date(startDate.year + year, month, 1) + timedelta(days=-1)
    if endDate >= endDate_max:
        endDate = endDate_max
    endDateformat = endDate.strftime('%Y-%m-%d')
    startDateformat = startDate.strftime('%Y-%m-%d')
    data = {"StartDate":startDateformat,"EndDate":endDateformat}
    print(data)
    response = nba_basketballreference_scraper(data)
    print(response)
    year, month= divmod(startDate.month+1, 12)
    if month == 0: 
          month = 12
          year = year -1
    startDate = date(startDate.year + year, month, 1)
# Out:
# {'StartDate': '1999-07-01', 'EndDate': '1999-07-31'}
# No data for july 1999 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '1999-08-01', 'EndDate': '1999-08-31'}
# No data for august 1999 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '1999-09-01', 'EndDate': '1999-09-30'}
# No data for september 1999 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '1999-10-01', 'EndDate': '1999-10-31'}
# No data for october 2000 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '1999-11-01', 'EndDate': '1999-11-30'}
# Loading data for november 2000
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-71-2b31db5b081d> in nba_basketballreference_scraper(request)
#     409                 job_game = client.load_table_from_dataframe(pandas_games_data, 'nba.raw_basketballreference_game', job_config=job_config)
# --> 410                 game_result = job_game.result()
#     411                 game_message = (
#
# c:\users\cwilb\source\repos\nba-predictions\.venv\lib\site-packages\google\cloud\bigquery\job\base.py in result(self, retry, timeout)
#     657         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 658         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     659
#
# c:\users\cwilb\source\repos\nba-predictions\.venv\lib\site-packages\google\api_core\future\polling.py in result(self, timeout, retry)
#     133             # Pylint doesn't recognize that this is valid in this case.
# --> 134             raise self._exception
#     135
#
# BadRequest: 400 Provided Schema does not match Table nba-predictions-dev:nba.raw_basketballreference_game. Field game_date has changed type from DATE to TIMESTAMP
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-2b31db5b081d> in nba_basketballreference_scraper(request)
#     419             except Exception as e:
# --> 420                 raise ValueError("Game data failed to load. See error and do not load player data") from e
#     421
#
# ValueError: Game data failed to load. See error and do not load player data
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-606e7fb281ee> in <module>
#      11     data = {"StartDate":startDateformat,"EndDate":endDateformat}
#      12     print(data)
# ---> 13     response = nba_basketballreference_scraper(data)
#      14     print(response)
#      15     year, month= divmod(startDate.month+1, 12)
#
# <ipython-input-71-2b31db5b081d> in nba_basketballreference_scraper(request)
#     452
#     453     except Exception as e:
# --> 454         raise ValueError("Load Job Failed - Check error log for specific details") from e
#     455
#     456     return f'Successfully loaded {player_game_rows_loaded} row(s) to raw_basketballreference_playerbox and {game_rows_loaded} to raw_basketballreference_game'
#
# ValueError: Load Job Failed - Check error log for specific details

# %%
game, player = nba_basketballreference_scraper({'StartDate':'1999-11-01', 'EndDate':'1999-11-30'})

# %%
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_date          209 non-null    datetime64[ns]
#  1   game_start_time    0 non-null      object
#  2   visitor_team_name  209 non-null    object
#  3   away_abbr          209 non-null    object
#  4   visitor_pts        209 non-null    object
#  5   home_team_name     209 non-null    object
#  6   home_abbr          209 non-null    object
#  7   home_pts           209 non-null    object
#  8   box_score_url      209 non-null    object
#  9   attendance         209 non-null    object
#  10  overtimes          209 non-null    object
#  11  game_key           209 non-null    object
#  12  a_g1_score         209 non-null    object
#  13  a_g2_score         209 non-null    object
#  14  a_g3_score         209 non-null    object
#  15  a_g4_score         209 non-null    object
#  16  h_g1_score         209 non-null    object
#  17  h_g2_score         209 non-null    object
#  18  h_g3_score         209 non-null    object
#  19  h_g4_score         209 non-null    object
#  20  a_ff_pace          209 non-null    object
#  21  a_ff_efg_pct       209 non-null    object
#  22  a_ff_tov_pct       209 non-null    object
#  23  a_ff_orb_pct       209 non-null    object
#  24  a_ff_ft_rate       209 non-null    object
#  25  a_ff_off_rtg       209 non-null    object
#  26  h_ff_pace          209 non-null    object
#  27  h_ff_efg_pct       209 non-null    object
#  28  h_ff_tov_pct       209 non-null    object
#  29  h_ff_orb_pct       209 non-null    object
#  30  h_ff_ft_rate       209 non-null    object
#  31  h_ff_off_rtg       209 non-null    object
#  32  load_datetime      209 non-null    datetime64[ns]
#  33  a_g5_score         8 non-null      object
#  34  h_g5_score         8 non-null      object
#  35  a_g6_score         1 non-null      object
#  36  h_g6_score         1 non-null      object
# dtypes: datetime64[ns](2), object(35)
# memory usage: 60.5+ KB

# %%
player
# Out:
# [{'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Eddie Jones',
#   'player_link': '/players/j/jonesed02.html',
#   'player_key': 'jonesed02',
#   'reason': None,
#   'mp': '42:00',
#   'fg': '8',
#   'fga': '22',
#   'fg_pct': '.364',
#   'fg3': '2',
#   'fg3a': '4',
#   'fg3_pct': '.500',
#   'ft': '6',
#   'fta': '7',
#   'ft_pct': '.857',
#   'orb': '2',
#   'drb': '5',
#   'trb': '7',
#   'ast': '2',
#   'stl': '4',
#   'blk': '1',
#   'tov': '3',
#   'pf': '4',
#   'pts': '24',
#   'plus_minus': '+25',
#   'player_stat_key': 'ORL19991102CHH|jonesed02|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'David Wesley',
#   'player_link': '/players/w/wesleda01.html',
#   'player_key': 'wesleda01',
#   'reason': None,
#   'mp': '32:45',
#   'fg': '5',
#   'fga': '11',
#   'fg_pct': '.455',
#   'fg3': '2',
#   'fg3a': '5',
#   'fg3_pct': '.400',
#   'ft': '4',
#   'fta': '6',
#   'ft_pct': '.667',
#   'orb': '0',
#   'drb': '4',
#   'trb': '4',
#   'ast': '9',
#   'stl': '5',
#   'blk': '0',
#   'tov': '4',
#   'pf': '2',
#   'pts': '16',
#   'plus_minus': '+14',
#   'player_stat_key': 'ORL19991102CHH|wesleda01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Anthony Mason',
#   'player_link': '/players/m/masonan01.html',
#   'player_key': 'masonan01',
#   'reason': None,
#   'mp': '32:13',
#   'fg': '3',
#   'fga': '5',
#   'fg_pct': '.600',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '3',
#   'drb': '5',
#   'trb': '8',
#   'ast': '3',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'pf': '4',
#   'pts': '7',
#   'plus_minus': '+17',
#   'player_stat_key': 'ORL19991102CHH|masonan01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Elden Campbell',
#   'player_link': '/players/c/campbel01.html',
#   'player_key': 'campbel01',
#   'reason': None,
#   'mp': '31:38',
#   'fg': '4',
#   'fga': '10',
#   'fg_pct': '.400',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '1',
#   'fta': '8',
#   'ft_pct': '.125',
#   'orb': '4',
#   'drb': '5',
#   'trb': '9',
#   'ast': '2',
#   'stl': '0',
#   'blk': '3',
#   'tov': '2',
#   'pf': '3',
#   'pts': '9',
#   'plus_minus': '+14',
#   'player_stat_key': 'ORL19991102CHH|campbel01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Bobby Phills',
#   'player_link': '/players/p/phillbo01.html',
#   'player_key': 'phillbo01',
#   'reason': None,
#   'mp': '30:38',
#   'fg': '8',
#   'fga': '16',
#   'fg_pct': '.500',
#   'fg3': '4',
#   'fg3a': '8',
#   'fg3_pct': '.500',
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '1',
#   'drb': '4',
#   'trb': '5',
#   'ast': '4',
#   'stl': '2',
#   'blk': '0',
#   'tov': '2',
#   'pf': '4',
#   'pts': '20',
#   'plus_minus': '+20',
#   'player_stat_key': 'ORL19991102CHH|phillbo01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Baron Davis',
#   'player_link': '/players/d/davisba01.html',
#   'player_key': 'davisba01',
#   'reason': None,
#   'mp': '25:07',
#   'fg': '3',
#   'fga': '6',
#   'fg_pct': '.500',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3_pct': '.333',
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '4',
#   'trb': '5',
#   'ast': '2',
#   'stl': '2',
#   'blk': '0',
#   'tov': '3',
#   'pf': '3',
#   'pts': '9',
#   'plus_minus': '+10',
#   'player_stat_key': 'ORL19991102CHH|davisba01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Derrick Coleman',
#   'player_link': '/players/c/colemde01.html',
#   'player_key': 'colemde01',
#   'reason': None,
#   'mp': '17:43',
#   'fg': '2',
#   'fga': '5',
#   'fg_pct': '.400',
#   'fg3': '1',
#   'fg3a': '1',
#   'fg3_pct': '1.000',
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '4',
#   'trb': '5',
#   'ast': '1',
#   'stl': '0',
#   'blk': '1',
#   'tov': '1',
#   'pf': '1',
#   'pts': '7',
#   'plus_minus': '+13',
#   'player_stat_key': 'ORL19991102CHH|colemde01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Brad Miller',
#   'player_link': '/players/m/millebr01.html',
#   'player_key': 'millebr01',
#   'reason': None,
#   'mp': '11:17',
#   'fg': '1',
#   'fga': '2',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '6',
#   'fta': '8',
#   'ft_pct': '.750',
#   'orb': '2',
#   'drb': '1',
#   'trb': '3',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'pf': '0',
#   'pts': '8',
#   'plus_minus': '-6',
#   'player_stat_key': 'ORL19991102CHH|millebr01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Todd Fuller',
#   'player_link': '/players/f/fulleto02.html',
#   'player_key': 'fulleto02',
#   'reason': None,
#   'mp': '8:37',
#   'fg': '0',
#   'fga': '4',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '2',
#   'ft_pct': '.000',
#   'orb': '0',
#   'drb': '1',
#   'trb': '1',
#   'ast': '1',
#   'stl': '0',
#   'blk': '0',
#   'tov': '1',
#   'pf': '2',
#   'pts': '0',
#   'plus_minus': '-8',
#   'player_stat_key': 'ORL19991102CHH|fulleto02|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Eddie Robinson',
#   'player_link': '/players/r/robined01.html',
#   'player_key': 'robined01',
#   'reason': None,
#   'mp': '3:12',
#   'fg': '0',
#   'fga': '0',
#   'fg_pct': None,
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '1',
#   'pf': '0',
#   'pts': '0',
#   'plus_minus': '-11',
#   'player_stat_key': 'ORL19991102CHH|robined01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Jason Miskiri',
#   'player_link': '/players/m/miskija01.html',
#   'player_key': 'miskija01',
#   'reason': None,
#   'mp': '3:12',
#   'fg': '0',
#   'fga': '1',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '1',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '2',
#   'pts': '0',
#   'plus_minus': '-11',
#   'player_stat_key': 'ORL19991102CHH|miskija01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'CHH',
#   'stat_period': 'game',
#   'player': 'Derek Hood',
#   'player_link': '/players/h/hoodde01.html',
#   'player_key': 'hoodde01',
#   'reason': None,
#   'mp': '1:38',
#   'fg': '0',
#   'fga': '0',
#   'fg_pct': None,
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '0',
#   'pts': '0',
#   'plus_minus': '-7',
#   'player_stat_key': 'ORL19991102CHH|hoodde01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Bo Outlaw',
#   'player_link': '/players/o/outlabo01.html',
#   'player_key': 'outlabo01',
#   'reason': None,
#   'mp': '31:17',
#   'fg': '2',
#   'fga': '3',
#   'fg_pct': '.667',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '2',
#   'drb': '4',
#   'trb': '6',
#   'ast': '0',
#   'stl': '2',
#   'blk': '1',
#   'tov': '1',
#   'pf': '3',
#   'pts': '4',
#   'plus_minus': '-20',
#   'player_stat_key': 'ORL19991102CHH|outlabo01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Darrell Armstrong',
#   'player_link': '/players/a/armstda01.html',
#   'player_key': 'armstda01',
#   'reason': None,
#   'mp': '26:48',
#   'fg': '5',
#   'fga': '15',
#   'fg_pct': '.333',
#   'fg3': '0',
#   'fg3a': '4',
#   'fg3_pct': '.000',
#   'ft': '2',
#   'fta': '4',
#   'ft_pct': '.500',
#   'orb': '1',
#   'drb': '2',
#   'trb': '3',
#   'ast': '3',
#   'stl': '3',
#   'blk': '0',
#   'tov': '3',
#   'pf': '1',
#   'pts': '12',
#   'plus_minus': '-20',
#   'player_stat_key': 'ORL19991102CHH|armstda01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Michael Doleac',
#   'player_link': '/players/d/doleami01.html',
#   'player_key': 'doleami01',
#   'reason': None,
#   'mp': '20:20',
#   'fg': '1',
#   'fga': '6',
#   'fg_pct': '.167',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '5',
#   'fta': '6',
#   'ft_pct': '.833',
#   'orb': '0',
#   'drb': '3',
#   'trb': '3',
#   'ast': '2',
#   'stl': '0',
#   'blk': '0',
#   'tov': '3',
#   'pf': '3',
#   'pts': '7',
#   'plus_minus': '-11',
#   'player_stat_key': 'ORL19991102CHH|doleami01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Tariq Abdul-Wahad',
#   'player_link': '/players/a/abdulta01.html',
#   'player_key': 'abdulta01',
#   'reason': None,
#   'mp': '19:34',
#   'fg': '2',
#   'fga': '7',
#   'fg_pct': '.286',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '2',
#   'drb': '2',
#   'trb': '4',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'pf': '1',
#   'pts': '4',
#   'plus_minus': '-15',
#   'player_stat_key': 'ORL19991102CHH|abdulta01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Ben Wallace',
#   'player_link': '/players/w/wallabe01.html',
#   'player_key': 'wallabe01',
#   'reason': None,
#   'mp': '13:50',
#   'fg': '1',
#   'fga': '1',
#   'fg_pct': '1.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '1',
#   'drb': '2',
#   'trb': '3',
#   'ast': '0',
#   'stl': '0',
#   'blk': '1',
#   'tov': '0',
#   'pf': '2',
#   'pts': '2',
#   'plus_minus': '-19',
#   'player_stat_key': 'ORL19991102CHH|wallabe01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Chris Gatling',
#   'player_link': '/players/g/gatlich01.html',
#   'player_key': 'gatlich01',
#   'reason': None,
#   'mp': '24:12',
#   'fg': '7',
#   'fga': '13',
#   'fg_pct': '.538',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '1',
#   'fta': '4',
#   'ft_pct': '.250',
#   'orb': '1',
#   'drb': '6',
#   'trb': '7',
#   'ast': '1',
#   'stl': '1',
#   'blk': '1',
#   'tov': '4',
#   'pf': '4',
#   'pts': '15',
#   'plus_minus': '-15',
#   'player_stat_key': 'ORL19991102CHH|gatlich01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Corey Maggette',
#   'player_link': '/players/m/maggeco01.html',
#   'player_key': 'maggeco01',
#   'reason': None,
#   'mp': '22:11',
#   'fg': '5',
#   'fga': '7',
#   'fg_pct': '.714',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '4',
#   'drb': '3',
#   'trb': '7',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '3',
#   'pf': '5',
#   'pts': '10',
#   'plus_minus': '+6',
#   'player_stat_key': 'ORL19991102CHH|maggeco01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Chucky Atkins',
#   'player_link': '/players/a/atkinch01.html',
#   'player_key': 'atkinch01',
#   'reason': None,
#   'mp': '21:12',
#   'fg': '4',
#   'fga': '10',
#   'fg_pct': '.400',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3_pct': '.000',
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '4',
#   'trb': '4',
#   'ast': '4',
#   'stl': '2',
#   'blk': '0',
#   'tov': '4',
#   'pf': '2',
#   'pts': '10',
#   'plus_minus': '+6',
#   'player_stat_key': 'ORL19991102CHH|atkinch01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Pat Garrity',
#   'player_link': '/players/g/garripa01.html',
#   'player_key': 'garripa01',
#   'reason': None,
#   'mp': '19:19',
#   'fg': '3',
#   'fga': '6',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3_pct': '.000',
#   'ft': '3',
#   'fta': '6',
#   'ft_pct': '.500',
#   'orb': '0',
#   'drb': '3',
#   'trb': '3',
#   'ast': '2',
#   'stl': '1',
#   'blk': '0',
#   'tov': '0',
#   'pf': '1',
#   'pts': '9',
#   'plus_minus': '+10',
#   'player_stat_key': 'ORL19991102CHH|garripa01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Monty Williams',
#   'player_link': '/players/w/willimo01.html',
#   'player_key': 'willimo01',
#   'reason': None,
#   'mp': '18:40',
#   'fg': '2',
#   'fga': '4',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '2',
#   'trb': '2',
#   'ast': '3',
#   'stl': '0',
#   'blk': '1',
#   'tov': '0',
#   'pf': '5',
#   'pts': '6',
#   'plus_minus': '-2',
#   'player_stat_key': 'ORL19991102CHH|willimo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'John Amaechi',
#   'player_link': '/players/a/amaecjo01.html',
#   'player_key': 'amaecjo01',
#   'reason': None,
#   'mp': '14:33',
#   'fg': '2',
#   'fga': '4',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '3',
#   'fta': '3',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '3',
#   'trb': '4',
#   'ast': '2',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'pf': '2',
#   'pts': '7',
#   'plus_minus': '+11',
#   'player_stat_key': 'ORL19991102CHH|amaecjo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'ORL19991102CHH',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'ORL',
#   'stat_period': 'game',
#   'player': 'Matt Harpring',
#   'player_link': '/players/h/harprma01.html',
#   'player_key': 'harprma01',
#   'reason': None,
#   'mp': '8:04',
#   'fg': '0',
#   'fga': '4',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '2',
#   'trb': '2',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '2',
#   'pts': '0',
#   'plus_minus': '-1',
#   'player_stat_key': 'ORL19991102CHH|harprma01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Erick Strickland',
#   'player_link': '/players/s/stricer01.html',
#   'player_key': 'stricer01',
#   'reason': None,
#   'mp': '43:39',
#   'fg': '2',
#   'fga': '11',
#   'fg_pct': '.182',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3_pct': '.000',
#   'ft': '8',
#   'fta': '10',
#   'ft_pct': '.800',
#   'orb': '0',
#   'drb': '6',
#   'trb': '6',
#   'ast': '5',
#   'stl': '3',
#   'blk': '0',
#   'tov': '1',
#   'pf': '3',
#   'pts': '12',
#   'plus_minus': '+20',
#   'player_stat_key': 'GSW19991102DAL|stricer01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Michael Finley',
#   'player_link': '/players/f/finlemi01.html',
#   'player_key': 'finlemi01',
#   'reason': None,
#   'mp': '42:55',
#   'fg': '12',
#   'fga': '23',
#   'fg_pct': '.522',
#   'fg3': '1',
#   'fg3a': '4',
#   'fg3_pct': '.250',
#   'ft': '1',
#   'fta': '1',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '6',
#   'trb': '7',
#   'ast': '4',
#   'stl': '0',
#   'blk': '2',
#   'tov': '2',
#   'pf': '4',
#   'pts': '26',
#   'plus_minus': '+10',
#   'player_stat_key': 'GSW19991102DAL|finlemi01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Robert Pack',
#   'player_link': '/players/p/packro01.html',
#   'player_key': 'packro01',
#   'reason': None,
#   'mp': '22:48',
#   'fg': '5',
#   'fga': '8',
#   'fg_pct': '.625',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '1',
#   'trb': '2',
#   'ast': '2',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'pf': '0',
#   'pts': '12',
#   'plus_minus': '+4',
#   'player_stat_key': 'GSW19991102DAL|packro01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Dirk Nowitzki',
#   'player_link': '/players/n/nowitdi01.html',
#   'player_key': 'nowitdi01',
#   'reason': None,
#   'mp': '22:07',
#   'fg': '2',
#   'fga': '5',
#   'fg_pct': '.400',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '5',
#   'fta': '7',
#   'ft_pct': '.714',
#   'orb': '2',
#   'drb': '5',
#   'trb': '7',
#   'ast': '3',
#   'stl': '1',
#   'blk': '0',
#   'tov': '0',
#   'pf': '4',
#   'pts': '9',
#   'plus_minus': '-6',
#   'player_stat_key': 'GSW19991102DAL|nowitdi01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Sean Rooks',
#   'player_link': '/players/r/rooksse01.html',
#   'player_key': 'rooksse01',
#   'reason': None,
#   'mp': '10:22',
#   'fg': '1',
#   'fga': '2',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '1',
#   'drb': '3',
#   'trb': '4',
#   'ast': '3',
#   'stl': '0',
#   'blk': '2',
#   'tov': '2',
#   'pf': '2',
#   'pts': '2',
#   'plus_minus': '+2',
#   'player_stat_key': 'GSW19991102DAL|rooksse01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Cedric Ceballos',
#   'player_link': '/players/c/cebalce01.html',
#   'player_key': 'cebalce01',
#   'reason': None,
#   'mp': '34:10',
#   'fg': '9',
#   'fga': '19',
#   'fg_pct': '.474',
#   'fg3': '0',
#   'fg3a': '4',
#   'fg3_pct': '.000',
#   'ft': '9',
#   'fta': '10',
#   'ft_pct': '.900',
#   'orb': '3',
#   'drb': '2',
#   'trb': '5',
#   'ast': '1',
#   'stl': '0',
#   'blk': '0',
#   'tov': '3',
#   'pf': '2',
#   'pts': '27',
#   'plus_minus': '+1',
#   'player_stat_key': 'GSW19991102DAL|cebalce01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Steve Nash',
#   'player_link': '/players/n/nashst01.html',
#   'player_key': 'nashst01',
#   'reason': None,
#   'mp': '25:12',
#   'fg': '2',
#   'fga': '5',
#   'fg_pct': '.400',
#   'fg3': '0',
#   'fg3a': '3',
#   'fg3_pct': '.000',
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '0',
#   'drb': '3',
#   'trb': '3',
#   'ast': '3',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '3',
#   'pts': '5',
#   'plus_minus': '+8',
#   'player_stat_key': 'GSW19991102DAL|nashst01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Hubert Davis',
#   'player_link': '/players/d/davishu01.html',
#   'player_key': 'davishu01',
#   'reason': None,
#   'mp': '20:00',
#   'fg': '2',
#   'fga': '5',
#   'fg_pct': '.400',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3_pct': '.500',
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '2',
#   'trb': '3',
#   'ast': '0',
#   'stl': '2',
#   'blk': '0',
#   'tov': '0',
#   'pf': '0',
#   'pts': '7',
#   'plus_minus': '+5',
#   'player_stat_key': 'GSW19991102DAL|davishu01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Shawn Bradley',
#   'player_link': '/players/b/bradlsh01.html',
#   'player_key': 'bradlsh01',
#   'reason': None,
#   'mp': '18:18',
#   'fg': '4',
#   'fga': '7',
#   'fg_pct': '.571',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '2',
#   'drb': '2',
#   'trb': '4',
#   'ast': '1',
#   'stl': '5',
#   'blk': '2',
#   'tov': '3',
#   'pf': '1',
#   'pts': '8',
#   'plus_minus': '+16',
#   'player_stat_key': 'GSW19991102DAL|bradlsh01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Randell Jackson',
#   'player_link': '/players/j/jacksra02.html',
#   'player_key': 'jacksra02',
#   'reason': None,
#   'mp': '0:29',
#   'fg': '0',
#   'fga': '0',
#   'fg_pct': None,
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '0',
#   'pts': '0',
#   'plus_minus': '0',
#   'player_stat_key': 'GSW19991102DAL|jacksra02|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DAL',
#   'stat_period': 'game',
#   'player': 'Kebu Stewart',
#   'player_link': '/players/s/stewake01.html',
#   'player_key': 'stewake01',
#   'reason': 'Did Not Dress',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
#   'ast': None,
#   'stl': None,
#   'blk': None,
#   'tov': None,
#   'pf': None,
#   'pts': None,
#   'plus_minus': None,
#   'player_stat_key': 'GSW19991102DAL|stewake01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Vonteego Cummings',
#   'player_link': '/players/c/cummivo01.html',
#   'player_key': 'cummivo01',
#   'reason': None,
#   'mp': '37:46',
#   'fg': '4',
#   'fga': '11',
#   'fg_pct': '.364',
#   'fg3': '2',
#   'fg3a': '5',
#   'fg3_pct': '.400',
#   'ft': '3',
#   'fta': '4',
#   'ft_pct': '.750',
#   'orb': '1',
#   'drb': '5',
#   'trb': '6',
#   'ast': '4',
#   'stl': '1',
#   'blk': '1',
#   'tov': '2',
#   'pf': '2',
#   'pts': '13',
#   'plus_minus': '-9',
#   'player_stat_key': 'GSW19991102DAL|cummivo01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Chris Mills',
#   'player_link': '/players/m/millsch01.html',
#   'player_key': 'millsch01',
#   'reason': None,
#   'mp': '34:52',
#   'fg': '6',
#   'fga': '12',
#   'fg_pct': '.500',
#   'fg3': '2',
#   'fg3a': '4',
#   'fg3_pct': '.500',
#   'ft': '4',
#   'fta': '4',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '6',
#   'trb': '7',
#   'ast': '1',
#   'stl': '1',
#   'blk': '0',
#   'tov': '3',
#   'pf': '4',
#   'pts': '18',
#   'plus_minus': '-10',
#   'player_stat_key': 'GSW19991102DAL|millsch01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Antawn Jamison',
#   'player_link': '/players/j/jamisan01.html',
#   'player_key': 'jamisan01',
#   'reason': None,
#   'mp': '31:58',
#   'fg': '3',
#   'fga': '13',
#   'fg_pct': '.231',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '3',
#   'fta': '4',
#   'ft_pct': '.750',
#   'orb': '4',
#   'drb': '3',
#   'trb': '7',
#   'ast': '1',
#   'stl': '0',
#   'blk': '0',
#   'tov': '5',
#   'pf': '4',
#   'pts': '9',
#   'plus_minus': '-20',
#   'player_stat_key': 'GSW19991102DAL|jamisan01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Tony Farmer',
#   'player_link': '/players/f/farmeto01.html',
#   'player_key': 'farmeto01',
#   'reason': None,
#   'mp': '15:08',
#   'fg': '3',
#   'fga': '5',
#   'fg_pct': '.600',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '3',
#   'fta': '4',
#   'ft_pct': '.750',
#   'orb': '2',
#   'drb': '2',
#   'trb': '4',
#   'ast': '1',
#   'stl': '0',
#   'blk': '0',
#   'tov': '1',
#   'pf': '2',
#   'pts': '9',
#   'plus_minus': '-2',
#   'player_stat_key': 'GSW19991102DAL|farmeto01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Adonal Foyle',
#   'player_link': '/players/f/foylead01.html',
#   'player_key': 'foylead01',
#   'reason': None,
#   'mp': '13:37',
#   'fg': '1',
#   'fga': '3',
#   'fg_pct': '.333',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '3',
#   'trb': '3',
#   'ast': '0',
#   'stl': '0',
#   'blk': '1',
#   'tov': '4',
#   'pf': '2',
#   'pts': '2',
#   'plus_minus': '-5',
#   'player_stat_key': 'GSW19991102DAL|foylead01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'John Starks',
#   'player_link': '/players/s/starkjo01.html',
#   'player_key': 'starkjo01',
#   'reason': None,
#   'mp': '35:47',
#   'fg': '8',
#   'fga': '14',
#   'fg_pct': '.571',
#   'fg3': '3',
#   'fg3a': '5',
#   'fg3_pct': '.600',
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '0',
#   'drb': '4',
#   'trb': '4',
#   'ast': '4',
#   'stl': '1',
#   'blk': '0',
#   'tov': '3',
#   'pf': '3',
#   'pts': '20',
#   'plus_minus': '-5',
#   'player_stat_key': 'GSW19991102DAL|starkjo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Terry Cummings',
#   'player_link': '/players/c/cummite01.html',
#   'player_key': 'cummite01',
#   'reason': None,
#   'mp': '21:08',
#   'fg': '3',
#   'fga': '8',
#   'fg_pct': '.375',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '4',
#   'fta': '6',
#   'ft_pct': '.667',
#   'orb': '6',
#   'drb': '2',
#   'trb': '8',
#   'ast': '0',
#   'stl': '1',
#   'blk': '0',
#   'tov': '0',
#   'pf': '4',
#   'pts': '10',
#   'plus_minus': '+6',
#   'player_stat_key': 'GSW19991102DAL|cummite01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Donyell Marshall',
#   'player_link': '/players/m/marshdo01.html',
#   'player_key': 'marshdo01',
#   'reason': None,
#   'mp': '20:11',
#   'fg': '3',
#   'fga': '9',
#   'fg_pct': '.333',
#   'fg3': '0',
#   'fg3a': '3',
#   'fg3_pct': '.000',
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '3',
#   'drb': '6',
#   'trb': '9',
#   'ast': '1',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'pf': '1',
#   'pts': '6',
#   'plus_minus': '-7',
#   'player_stat_key': 'GSW19991102DAL|marshdo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Jason Caffey',
#   'player_link': '/players/c/caffeja01.html',
#   'player_key': 'caffeja01',
#   'reason': None,
#   'mp': '15:13',
#   'fg': '3',
#   'fga': '6',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '3',
#   'fta': '3',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '1',
#   'trb': '2',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '4',
#   'pts': '9',
#   'plus_minus': '0',
#   'player_stat_key': 'GSW19991102DAL|caffeja01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Damon Jones',
#   'player_link': '/players/j/jonesda01.html',
#   'player_key': 'jonesda01',
#   'reason': None,
#   'mp': '10:02',
#   'fg': '0',
#   'fga': '0',
#   'fg_pct': None,
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '1',
#   'trb': '1',
#   'ast': '2',
#   'stl': '0',
#   'blk': '0',
#   'tov': '3',
#   'pf': '1',
#   'pts': '0',
#   'plus_minus': '-3',
#   'player_stat_key': 'GSW19991102DAL|jonesda01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Tim Legler',
#   'player_link': '/players/l/legleti01.html',
#   'player_key': 'legleti01',
#   'reason': None,
#   'mp': '4:18',
#   'fg': '0',
#   'fga': '1',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '2',
#   'pts': '0',
#   'plus_minus': '-5',
#   'player_stat_key': 'GSW19991102DAL|legleti01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'GSW19991102DAL',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'GSW',
#   'stat_period': 'game',
#   'player': 'Mookie Blaylock',
#   'player_link': '/players/b/blaylmo01.html',
#   'player_key': 'blaylmo01',
#   'reason': 'Did Not Dress',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
#   'ast': None,
#   'stl': None,
#   'blk': None,
#   'tov': None,
#   'pf': None,
#   'pts': None,
#   'plus_minus': None,
#   'player_stat_key': 'GSW19991102DAL|blaylmo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:42'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Ron Mercer',
#   'player_link': '/players/m/mercero01.html',
#   'player_key': 'mercero01',
#   'reason': None,
#   'mp': '46:46',
#   'fg': '6',
#   'fga': '17',
#   'fg_pct': '.353',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '4',
#   'fta': '5',
#   'ft_pct': '.800',
#   'orb': '0',
#   'drb': '6',
#   'trb': '6',
#   'ast': '4',
#   'stl': '1',
#   'blk': '0',
#   'tov': '1',
#   'pf': '1',
#   'pts': '16',
#   'plus_minus': '+7',
#   'player_stat_key': 'PHO19991102DEN|mercero01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Nick Van Exel',
#   'player_link': '/players/v/vanexni01.html',
#   'player_key': 'vanexni01',
#   'reason': None,
#   'mp': '45:33',
#   'fg': '12',
#   'fga': '21',
#   'fg_pct': '.571',
#   'fg3': '5',
#   'fg3a': '7',
#   'fg3_pct': '.714',
#   'ft': '5',
#   'fta': '7',
#   'ft_pct': '.714',
#   'orb': '2',
#   'drb': '7',
#   'trb': '9',
#   'ast': '9',
#   'stl': '0',
#   'blk': '0',
#   'tov': '3',
#   'pf': '1',
#   'pts': '34',
#   'plus_minus': '+21',
#   'player_stat_key': 'PHO19991102DEN|vanexni01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Antonio McDyess',
#   'player_link': '/players/m/mcdyean01.html',
#   'player_key': 'mcdyean01',
#   'reason': None,
#   'mp': '45:05',
#   'fg': '7',
#   'fga': '15',
#   'fg_pct': '.467',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '4',
#   'fta': '6',
#   'ft_pct': '.667',
#   'orb': '2',
#   'drb': '5',
#   'trb': '7',
#   'ast': '4',
#   'stl': '0',
#   'blk': '4',
#   'tov': '7',
#   'pf': '3',
#   'pts': '18',
#   'plus_minus': '+20',
#   'player_stat_key': 'PHO19991102DEN|mcdyean01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Raef LaFrentz',
#   'player_link': '/players/l/lafrera01.html',
#   'player_key': 'lafrera01',
#   'reason': None,
#   'mp': '31:01',
#   'fg': '4',
#   'fga': '10',
#   'fg_pct': '.400',
#   'fg3': '1',
#   'fg3a': '3',
#   'fg3_pct': '.333',
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '0',
#   'drb': '8',
#   'trb': '8',
#   'ast': '0',
#   'stl': '1',
#   'blk': '5',
#   'tov': '0',
#   'pf': '3',
#   'pts': '10',
#   'plus_minus': '-1',
#   'player_stat_key': 'PHO19991102DEN|lafrera01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'James Posey',
#   'player_link': '/players/p/poseyja01.html',
#   'player_key': 'poseyja01',
#   'reason': None,
#   'mp': '20:00',
#   'fg': '4',
#   'fga': '5',
#   'fg_pct': '.800',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '0',
#   'drb': '2',
#   'trb': '2',
#   'ast': '1',
#   'stl': '1',
#   'blk': '1',
#   'tov': '1',
#   'pf': '2',
#   'pts': '9',
#   'plus_minus': '+7',
#   'player_stat_key': 'PHO19991102DEN|poseyja01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'George McCloud',
#   'player_link': '/players/m/mccloge01.html',
#   'player_key': 'mccloge01',
#   'reason': None,
#   'mp': '33:00',
#   'fg': '6',
#   'fga': '15',
#   'fg_pct': '.400',
#   'fg3': '2',
#   'fg3a': '5',
#   'fg3_pct': '.400',
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '2',
#   'drb': '7',
#   'trb': '9',
#   'ast': '2',
#   'stl': '0',
#   'blk': '3',
#   'tov': '2',
#   'pf': '2',
#   'pts': '16',
#   'plus_minus': '-2',
#   'player_stat_key': 'PHO19991102DEN|mccloge01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Roy Rogers',
#   'player_link': '/players/r/rogerro02.html',
#   'player_key': 'rogerro02',
#   'reason': None,
#   'mp': '12:23',
#   'fg': '0',
#   'fga': '0',
#   'fg_pct': None,
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '3',
#   'drb': '5',
#   'trb': '8',
#   'ast': '1',
#   'stl': '0',
#   'blk': '2',
#   'tov': '0',
#   'pf': '0',
#   'pts': '0',
#   'plus_minus': '+4',
#   'player_stat_key': 'PHO19991102DEN|rogerro02|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Ryan Bowen',
#   'player_link': '/players/b/bowenry01.html',
#   'player_key': 'bowenry01',
#   'reason': None,
#   'mp': '9:36',
#   'fg': '1',
#   'fga': '3',
#   'fg_pct': '.333',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '2',
#   'drb': '1',
#   'trb': '3',
#   'ast': '1',
#   'stl': '2',
#   'blk': '0',
#   'tov': '0',
#   'pf': '1',
#   'pts': '4',
#   'plus_minus': '+2',
#   'player_stat_key': 'PHO19991102DEN|bowenry01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Keon Clark',
#   'player_link': '/players/c/clarkke01.html',
#   'player_key': 'clarkke01',
#   'reason': None,
#   'mp': '7:55',
#   'fg': '0',
#   'fga': '1',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '2',
#   'drb': '0',
#   'trb': '2',
#   'ast': '0',
#   'stl': '1',
#   'blk': '0',
#   'tov': '2',
#   'pf': '2',
#   'pts': '0',
#   'plus_minus': '-15',
#   'player_stat_key': 'PHO19991102DEN|clarkke01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Cory Alexander',
#   'player_link': '/players/a/alexaco01.html',
#   'player_key': 'alexaco01',
#   'reason': None,
#   'mp': '7:27',
#   'fg': '0',
#   'fga': '0',
#   'fg_pct': None,
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '1',
#   'trb': '1',
#   'ast': '2',
#   'stl': '0',
#   'blk': '0',
#   'tov': '1',
#   'pf': '2',
#   'pts': '0',
#   'plus_minus': '-16',
#   'player_stat_key': 'PHO19991102DEN|alexaco01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Bryant Stith',
#   'player_link': '/players/s/stithbr01.html',
#   'player_key': 'stithbr01',
#   'reason': None,
#   'mp': '6:14',
#   'fg': '0',
#   'fga': '2',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '1',
#   'stl': '0',
#   'blk': '1',
#   'tov': '1',
#   'pf': '0',
#   'pts': '0',
#   'plus_minus': '-2',
#   'player_stat_key': 'PHO19991102DEN|stithbr01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'h',
#   'team_abbrev': 'DEN',
#   'stat_period': 'game',
#   'player': 'Johnny Taylor',
#   'player_link': '/players/t/taylojo01.html',
#   'player_key': 'taylojo01',
#   'reason': 'Did Not Play',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
#   'ast': None,
#   'stl': None,
#   'blk': None,
#   'tov': None,
#   'pf': None,
#   'pts': None,
#   'plus_minus': None,
#   'player_stat_key': 'PHO19991102DEN|taylojo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Clifford Robinson',
#   'player_link': '/players/r/robincl02.html',
#   'player_key': 'robincl02',
#   'reason': None,
#   'mp': '48:01',
#   'fg': '6',
#   'fga': '16',
#   'fg_pct': '.375',
#   'fg3': '4',
#   'fg3a': '11',
#   'fg3_pct': '.364',
#   'ft': '4',
#   'fta': '4',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '3',
#   'trb': '4',
#   'ast': '2',
#   'stl': '1',
#   'blk': '1',
#   'tov': '1',
#   'pf': '4',
#   'pts': '20',
#   'plus_minus': '-13',
#   'player_stat_key': 'PHO19991102DEN|robincl02|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Tom Gugliotta',
#   'player_link': '/players/g/guglito01.html',
#   'player_key': 'guglito01',
#   'reason': None,
#   'mp': '47:22',
#   'fg': '11',
#   'fga': '28',
#   'fg_pct': '.393',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '0',
#   'fta': '5',
#   'ft_pct': '.000',
#   'orb': '9',
#   'drb': '10',
#   'trb': '19',
#   'ast': '4',
#   'stl': '3',
#   'blk': '0',
#   'tov': '4',
#   'pf': '3',
#   'pts': '22',
#   'plus_minus': '+9',
#   'player_stat_key': 'PHO19991102DEN|guglito01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Jason Kidd',
#   'player_link': '/players/k/kiddja01.html',
#   'player_key': 'kiddja01',
#   'reason': None,
#   'mp': '43:29',
#   'fg': '3',
#   'fga': '12',
#   'fg_pct': '.250',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3_pct': '.500',
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '0',
#   'drb': '5',
#   'trb': '5',
#   'ast': '8',
#   'stl': '1',
#   'blk': '0',
#   'tov': '1',
#   'pf': '6',
#   'pts': '8',
#   'plus_minus': '-17',
#   'player_stat_key': 'PHO19991102DEN|kiddja01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Shawn Marion',
#   'player_link': '/players/m/mariosh01.html',
#   'player_key': 'mariosh01',
#   'reason': None,
#   'mp': '35:05',
#   'fg': '7',
#   'fga': '17',
#   'fg_pct': '.412',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '5',
#   'drb': '9',
#   'trb': '14',
#   'ast': '3',
#   'stl': '0',
#   'blk': '2',
#   'tov': '2',
#   'pf': '4',
#   'pts': '14',
#   'plus_minus': '+7',
#   'player_stat_key': 'PHO19991102DEN|mariosh01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Luc Longley',
#   'player_link': '/players/l/longllu01.html',
#   'player_key': 'longllu01',
#   'reason': None,
#   'mp': '24:23',
#   'fg': '4',
#   'fga': '8',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '1',
#   'fta': '1',
#   'ft_pct': '1.000',
#   'orb': '1',
#   'drb': '3',
#   'trb': '4',
#   'ast': '4',
#   'stl': '1',
#   'blk': '0',
#   'tov': '2',
#   'pf': '1',
#   'pts': '9',
#   'plus_minus': '+10',
#   'player_stat_key': 'PHO19991102DEN|longllu01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Rodney Rogers',
#   'player_link': '/players/r/rogerro01.html',
#   'player_key': 'rogerro01',
#   'reason': None,
#   'mp': '35:10',
#   'fg': '8',
#   'fga': '19',
#   'fg_pct': '.421',
#   'fg3': '4',
#   'fg3a': '6',
#   'fg3_pct': '.667',
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '5',
#   'drb': '2',
#   'trb': '7',
#   'ast': '4',
#   'stl': '2',
#   'blk': '2',
#   'tov': '2',
#   'pf': '4',
#   'pts': '21',
#   'plus_minus': '-15',
#   'player_stat_key': 'PHO19991102DEN|rogerro01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Randy Livingston',
#   'player_link': '/players/l/livinra01.html',
#   'player_key': 'livinra01',
#   'reason': None,
#   'mp': '27:30',
#   'fg': '4',
#   'fga': '10',
#   'fg_pct': '.400',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '5',
#   'trb': '5',
#   'ast': '4',
#   'stl': '1',
#   'blk': '0',
#   'tov': '1',
#   'pf': '4',
#   'pts': '8',
#   'plus_minus': '+4',
#   'player_stat_key': 'PHO19991102DEN|livinra01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Oliver Miller',
#   'player_link': '/players/m/milleol01.html',
#   'player_key': 'milleol01',
#   'reason': None,
#   'mp': '4:00',
#   'fg': '0',
#   'fga': '1',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '2',
#   'pts': '0',
#   'plus_minus': '-10',
#   'player_stat_key': 'PHO19991102DEN|milleol01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Mark West',
#   'player_link': '/players/w/westma01.html',
#   'player_key': 'westma01',
#   'reason': 'Did Not Play',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
#   'ast': None,
#   'stl': None,
#   'blk': None,
#   'tov': None,
#   'pf': None,
#   'pts': None,
#   'plus_minus': None,
#   'player_stat_key': 'PHO19991102DEN|westma01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Anfernee Hardaway',
#   'player_link': '/players/h/hardaan01.html',
#   'player_key': 'hardaan01',
#   'reason': 'Player Suspended',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
#   'ast': None,
#   'stl': None,
#   'blk': None,
#   'tov': None,
#   'pf': None,
#   'pts': None,
#   'plus_minus': None,
#   'player_stat_key': 'PHO19991102DEN|hardaan01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Todd Day',
#   'player_link': '/players/d/dayto01.html',
#   'player_key': 'dayto01',
#   'reason': 'Did Not Dress',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
#   'ast': None,
#   'stl': None,
#   'blk': None,
#   'tov': None,
#   'pf': None,
#   'pts': None,
#   'plus_minus': None,
#   'player_stat_key': 'PHO19991102DEN|dayto01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:21:43'},
#  {'game_key': 'PHO19991102DEN',
#   'game_date': '1999-11-02',
#   'h_or_a': 'a',
#   'team_abbrev': 'PHO',
#   'stat_period': 'game',
#   'player': 'Rex Chapman',
#   'player_link': '/players/c/chapmre01.html',
#   'player_key': 'chapmre01',
#   'reason': 'Player Suspended',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
# ...
#   'fg_pct': '.750',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '1',
#   'drb': '2',
#   'trb': '3',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '3',
#   'pts': '7',
#   'plus_minus': '-5',
#   'player_stat_key': 'SAC19991106MIN|pollasc01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:04'},
#  {'game_key': 'SAC19991106MIN',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'SAC',
#   'stat_period': 'game',
#   'player': 'Jon Barry',
#   'player_link': '/players/b/barryjo01.html',
#   'player_key': 'barryjo01',
#   'reason': None,
#   'mp': '14:51',
#   'fg': '2',
#   'fga': '4',
#   'fg_pct': '.500',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3_pct': '.500',
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '1',
#   'trb': '1',
#   'ast': '2',
#   'stl': '3',
#   'blk': '1',
#   'tov': '2',
#   'pf': '2',
#   'pts': '7',
#   'plus_minus': '-4',
#   'player_stat_key': 'SAC19991106MIN|barryjo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:04'},
#  {'game_key': 'SAC19991106MIN',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'SAC',
#   'stat_period': 'game',
#   'player': 'Lawrence Funderburke',
#   'player_link': '/players/f/fundela01.html',
#   'player_key': 'fundela01',
#   'reason': None,
#   'mp': '12:46',
#   'fg': '2',
#   'fga': '5',
#   'fg_pct': '.400',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '1',
#   'fta': '4',
#   'ft_pct': '.250',
#   'orb': '2',
#   'drb': '2',
#   'trb': '4',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '1',
#   'pts': '5',
#   'plus_minus': '-4',
#   'player_stat_key': 'SAC19991106MIN|fundela01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:04'},
#  {'game_key': 'SAC19991106MIN',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'SAC',
#   'stat_period': 'game',
#   'player': 'Tony Delk',
#   'player_link': '/players/d/delkto01.html',
#   'player_key': 'delkto01',
#   'reason': None,
#   'mp': '6:44',
#   'fg': '0',
#   'fga': '1',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '4',
#   'stl': '1',
#   'blk': '0',
#   'tov': '1',
#   'pf': '0',
#   'pts': '0',
#   'plus_minus': '+1',
#   'player_stat_key': 'SAC19991106MIN|delkto01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:04'},
#  {'game_key': 'SAC19991106MIN',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'SAC',
#   'stat_period': 'game',
#   'player': 'Tyrone Corbin',
#   'player_link': '/players/c/corbity01.html',
#   'player_key': 'corbity01',
#   'reason': 'Did Not Play',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
#   'ast': None,
#   'stl': None,
#   'blk': None,
#   'tov': None,
#   'pf': None,
#   'pts': None,
#   'plus_minus': None,
#   'player_stat_key': 'SAC19991106MIN|corbity01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:04'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Scottie Pippen',
#   'player_link': '/players/p/pippesc01.html',
#   'player_key': 'pippesc01',
#   'reason': None,
#   'mp': '41:23',
#   'fg': '8',
#   'fga': '17',
#   'fg_pct': '.471',
#   'fg3': '0',
#   'fg3a': '3',
#   'fg3_pct': '.000',
#   'ft': '3',
#   'fta': '4',
#   'ft_pct': '.750',
#   'orb': '0',
#   'drb': '8',
#   'trb': '8',
#   'ast': '5',
#   'stl': '2',
#   'blk': '1',
#   'tov': '3',
#   'pf': '1',
#   'pts': '19',
#   'plus_minus': '+20',
#   'player_stat_key': 'LAL19991106POR|pippesc01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Damon Stoudamire',
#   'player_link': '/players/s/stoudda01.html',
#   'player_key': 'stoudda01',
#   'reason': None,
#   'mp': '31:05',
#   'fg': '7',
#   'fga': '13',
#   'fg_pct': '.538',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3_pct': '.000',
#   'ft': '3',
#   'fta': '3',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '2',
#   'trb': '2',
#   'ast': '5',
#   'stl': '0',
#   'blk': '0',
#   'tov': '1',
#   'pf': '2',
#   'pts': '17',
#   'plus_minus': '+3',
#   'player_stat_key': 'LAL19991106POR|stoudda01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Steve Smith',
#   'player_link': '/players/s/smithst01.html',
#   'player_key': 'smithst01',
#   'reason': None,
#   'mp': '27:42',
#   'fg': '1',
#   'fga': '5',
#   'fg_pct': '.200',
#   'fg3': '1',
#   'fg3a': '2',
#   'fg3_pct': '.500',
#   'ft': '4',
#   'fta': '4',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '3',
#   'trb': '3',
#   'ast': '3',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'pf': '3',
#   'pts': '7',
#   'plus_minus': '+1',
#   'player_stat_key': 'LAL19991106POR|smithst01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Detlef Schrempf',
#   'player_link': '/players/s/schrede01.html',
#   'player_key': 'schrede01',
#   'reason': None,
#   'mp': '25:22',
#   'fg': '6',
#   'fga': '7',
#   'fg_pct': '.857',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '2',
#   'drb': '4',
#   'trb': '6',
#   'ast': '2',
#   'stl': '0',
#   'blk': '0',
#   'tov': '1',
#   'pf': '4',
#   'pts': '12',
#   'plus_minus': '+9',
#   'player_stat_key': 'LAL19991106POR|schrede01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Arvydas Sabonis',
#   'player_link': '/players/s/sabonar01.html',
#   'player_key': 'sabonar01',
#   'reason': None,
#   'mp': '24:01',
#   'fg': '7',
#   'fga': '11',
#   'fg_pct': '.636',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '3',
#   'fta': '3',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '6',
#   'trb': '6',
#   'ast': '1',
#   'stl': '0',
#   'blk': '2',
#   'tov': '1',
#   'pf': '5',
#   'pts': '17',
#   'plus_minus': '+7',
#   'player_stat_key': 'LAL19991106POR|sabonar01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Bonzi Wells',
#   'player_link': '/players/w/wellsbo01.html',
#   'player_key': 'wellsbo01',
#   'reason': None,
#   'mp': '25:26',
#   'fg': '5',
#   'fga': '7',
#   'fg_pct': '.714',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '3',
#   'trb': '3',
#   'ast': '2',
#   'stl': '1',
#   'blk': '0',
#   'tov': '2',
#   'pf': '2',
#   'pts': '12',
#   'plus_minus': '+13',
#   'player_stat_key': 'LAL19991106POR|wellsbo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Stacey Augmon',
#   'player_link': '/players/a/augmost01.html',
#   'player_key': 'augmost01',
#   'reason': None,
#   'mp': '20:24',
#   'fg': '1',
#   'fga': '1',
#   'fg_pct': '1.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '2',
#   'drb': '5',
#   'trb': '7',
#   'ast': '1',
#   'stl': '1',
#   'blk': '0',
#   'tov': '1',
#   'pf': '1',
#   'pts': '2',
#   'plus_minus': '+3',
#   'player_stat_key': 'LAL19991106POR|augmost01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Greg Anthony',
#   'player_link': '/players/a/anthogr01.html',
#   'player_key': 'anthogr01',
#   'reason': None,
#   'mp': '16:56',
#   'fg': '1',
#   'fga': '4',
#   'fg_pct': '.250',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3_pct': '.000',
#   'ft': '5',
#   'fta': '5',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '0',
#   'trb': '0',
#   'ast': '1',
#   'stl': '2',
#   'blk': '0',
#   'tov': '3',
#   'pf': '2',
#   'pts': '7',
#   'plus_minus': '+12',
#   'player_stat_key': 'LAL19991106POR|anthogr01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Antonio Harvey',
#   'player_link': '/players/h/harvean01.html',
#   'player_key': 'harvean01',
#   'reason': None,
#   'mp': '12:35',
#   'fg': '1',
#   'fga': '2',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '1',
#   'drb': '1',
#   'trb': '2',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '2',
#   'pf': '4',
#   'pts': '2',
#   'plus_minus': '+2',
#   'player_stat_key': 'LAL19991106POR|harvean01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Joe Kleine',
#   'player_link': '/players/k/kleinjo01.html',
#   'player_key': 'kleinjo01',
#   'reason': None,
#   'mp': '10:18',
#   'fg': '1',
#   'fga': '2',
#   'fg_pct': '.500',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '2',
#   'trb': '2',
#   'ast': '1',
#   'stl': '1',
#   'blk': '0',
#   'tov': '0',
#   'pf': '4',
#   'pts': '2',
#   'plus_minus': '+12',
#   'player_stat_key': 'LAL19991106POR|kleinjo01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': "Jermaine O\\'Neal",
#   'player_link': '/players/o/onealje01.html',
#   'player_key': 'onealje01',
#   'reason': None,
#   'mp': '4:48',
#   'fg': '0',
#   'fga': '0',
#   'fg_pct': None,
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '0',
#   'drb': '1',
#   'trb': '1',
#   'ast': '0',
#   'stl': '0',
#   'blk': '0',
#   'tov': '1',
#   'pf': '5',
#   'pts': '0',
#   'plus_minus': '-7',
#   'player_stat_key': 'LAL19991106POR|onealje01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'h',
#   'team_abbrev': 'POR',
#   'stat_period': 'game',
#   'player': 'Rasheed Wallace',
#   'player_link': '/players/w/wallara01.html',
#   'player_key': 'wallara01',
#   'reason': 'Did Not Dress',
#   'mp': None,
#   'fg': None,
#   'fga': None,
#   'fg_pct': None,
#   'fg3': None,
#   'fg3a': None,
#   'fg3_pct': None,
#   'ft': None,
#   'fta': None,
#   'ft_pct': None,
#   'orb': None,
#   'drb': None,
#   'trb': None,
#   'ast': None,
#   'stl': None,
#   'blk': None,
#   'tov': None,
#   'pf': None,
#   'pts': None,
#   'plus_minus': None,
#   'player_stat_key': 'LAL19991106POR|wallara01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'LAL',
#   'stat_period': 'game',
#   'player': 'Glen Rice',
#   'player_link': '/players/r/ricegl01.html',
#   'player_key': 'ricegl01',
#   'reason': None,
#   'mp': '35:38',
#   'fg': '5',
#   'fga': '11',
#   'fg_pct': '.455',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3_pct': '.000',
#   'ft': '4',
#   'fta': '5',
#   'ft_pct': '.800',
#   'orb': '1',
#   'drb': '1',
#   'trb': '2',
#   'ast': '2',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '1',
#   'pts': '14',
#   'plus_minus': '-17',
#   'player_stat_key': 'LAL19991106POR|ricegl01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'LAL',
#   'stat_period': 'game',
#   'player': "Shaquille O\\'Neal",
#   'player_link': '/players/o/onealsh01.html',
#   'player_key': 'onealsh01',
#   'reason': None,
#   'mp': '33:08',
#   'fg': '9',
#   'fga': '14',
#   'fg_pct': '.643',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '3',
#   'fta': '11',
#   'ft_pct': '.273',
#   'orb': '4',
#   'drb': '6',
#   'trb': '10',
#   'ast': '0',
#   'stl': '0',
#   'blk': '2',
#   'tov': '2',
#   'pf': '0',
#   'pts': '21',
#   'plus_minus': '-5',
#   'player_stat_key': 'LAL19991106POR|onealsh01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'LAL',
#   'stat_period': 'game',
#   'player': 'Ron Harper',
#   'player_link': '/players/h/harpero01.html',
#   'player_key': 'harpero01',
#   'reason': None,
#   'mp': '29:27',
#   'fg': '1',
#   'fga': '5',
#   'fg_pct': '.200',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '0',
#   'fta': '0',
#   'ft_pct': None,
#   'orb': '1',
#   'drb': '4',
#   'trb': '5',
#   'ast': '6',
#   'stl': '0',
#   'blk': '1',
#   'tov': '5',
#   'pf': '4',
#   'pts': '2',
#   'plus_minus': '-4',
#   'player_stat_key': 'LAL19991106POR|harpero01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'LAL',
#   'stat_period': 'game',
#   'player': 'A.C. Green',
#   'player_link': '/players/g/greenac01.html',
#   'player_key': 'greenac01',
#   'reason': None,
#   'mp': '26:35',
#   'fg': '3',
#   'fga': '10',
#   'fg_pct': '.300',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '5',
#   'fta': '8',
#   'ft_pct': '.625',
#   'orb': '7',
#   'drb': '3',
#   'trb': '10',
#   'ast': '0',
#   'stl': '2',
#   'blk': '0',
#   'tov': '0',
#   'pf': '2',
#   'pts': '11',
#   'plus_minus': '-4',
#   'player_stat_key': 'LAL19991106POR|greenac01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'LAL',
#   'stat_period': 'game',
#   'player': 'Derek Fisher',
#   'player_link': '/players/f/fishede01.html',
#   'player_key': 'fishede01',
#   'reason': None,
#   'mp': '25:45',
#   'fg': '1',
#   'fga': '6',
#   'fg_pct': '.167',
#   'fg3': '0',
#   'fg3a': '1',
#   'fg3_pct': '.000',
#   'ft': '2',
#   'fta': '2',
#   'ft_pct': '1.000',
#   'orb': '0',
#   'drb': '1',
#   'trb': '1',
#   'ast': '1',
#   'stl': '2',
#   'blk': '0',
#   'tov': '0',
#   'pf': '4',
#   'pts': '4',
#   'plus_minus': '-5',
#   'player_stat_key': 'LAL19991106POR|fishede01|game',
#   'starter_flag': True,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'LAL',
#   'stat_period': 'game',
#   'player': 'Tyronn Lue',
#   'player_link': '/players/l/luety01.html',
#   'player_key': 'luety01',
#   'reason': None,
#   'mp': '22:16',
#   'fg': '5',
#   'fga': '9',
#   'fg_pct': '.556',
#   'fg3': '0',
#   'fg3a': '2',
#   'fg3_pct': '.000',
#   'ft': '2',
#   'fta': '4',
#   'ft_pct': '.500',
#   'orb': '0',
#   'drb': '1',
#   'trb': '1',
#   'ast': '3',
#   'stl': '2',
#   'blk': '0',
#   'tov': '2',
#   'pf': '3',
#   'pts': '12',
#   'plus_minus': '-10',
#   'player_stat_key': 'LAL19991106POR|luety01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  {'game_key': 'LAL19991106POR',
#   'game_date': '1999-11-06',
#   'h_or_a': 'a',
#   'team_abbrev': 'LAL',
#   'stat_period': 'game',
#   'player': 'Brian Shaw',
#   'player_link': '/players/s/shawbr01.html',
#   'player_key': 'shawbr01',
#   'reason': None,
#   'mp': '17:44',
#   'fg': '0',
#   'fga': '3',
#   'fg_pct': '.000',
#   'fg3': '0',
#   'fg3a': '0',
#   'fg3_pct': None,
#   'ft': '1',
#   'fta': '2',
#   'ft_pct': '.500',
#   'orb': '0',
#   'drb': '3',
#   'trb': '3',
#   'ast': '2',
#   'stl': '0',
#   'blk': '0',
#   'tov': '0',
#   'pf': '4',
#   'pts': '1',
#   'plus_minus': '-13',
#   'player_stat_key': 'LAL19991106POR|shawbr01|game',
#   'starter_flag': False,
#   'load_datetime': '2021-02-27 12:22:05'},
#  ...]
