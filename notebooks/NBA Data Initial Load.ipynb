# %%
import requests
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import pandas as pd
from google.cloud import bigquery
import os



def get_max_game_date():
    project_id = os.environ.get('GCP_PROJECT')
    client = bigquery.Client(project=project_id)
    
    QUERY = (
    "SELECT date_add(max(game_date), INTERVAL 1 day) as max_game_date FROM `nba.raw_basketballreference_game`"
    )
    query_job = client.query(QUERY)  # API request
    rows = query_job.result()  # Waits for query to finish
    
    for result in rows:
        load_date = result.max_game_date
    
    return load_date

def get_game_players(soup, player_game_data, id_string, game_key, stat_type, h_or_a, team_abbrev, game_date):
    rows = soup.find('table', id=id_string).find('tbody').find_all('tr')
    cnt = 1

    #print(str(rows))
    for player in rows:
        game_players = {}
        game_players['game_key'] = game_key
        game_players['game_date'] = game_date
        game_players['h_or_a'] = h_or_a
        game_players['team_abbrev'] = team_abbrev
        game_players['stat_period'] = stat_type
        game_players['player'] = player.find('th',{"data-stat": "player"}).text
        #print(game_players['player'])
        
        player_node = player.find('th',{"data-stat": "player"})
        
        # Ignore Header Line
        if game_players['player'] != 'Reserves' and player_node.has_attr('data-append-csv'):
        
            a = player.find('th',{"data-stat": "player"}).find('a',href=True)
            if a is not None:
                game_players['player_link'] = a['href']
            else:
                game_players['player_link'] = None
            
            game_players['player_key'] = player_node['data-append-csv']
            game_players['reason'] = get_text(player.find('td',{"data-stat": "reason"}))
            game_players['mp'] = get_text(player.find('td',{"data-stat": "mp"}))
            game_players['fg'] = get_text(player.find('td',{"data-stat": "fg"}))
            game_players['fga'] = get_text(player.find('td',{"data-stat": "fga"}))
            game_players['fg_pct'] = get_text(player.find('td',{"data-stat": "fg_pct"}))
            game_players['fg3'] = get_text(player.find('td',{"data-stat": "fg3"}))
            game_players['fg3a'] = get_text(player.find('td',{"data-stat": "fg3a"}))
            game_players['fg3_pct'] = get_text(player.find('td',{"data-stat": "fg3_pct"}))
            game_players['ft'] = get_text(player.find('td',{"data-stat": "ft"}))
            game_players['fta'] = get_text(player.find('td',{"data-stat": "fta"}))
            game_players['ft_pct'] = get_text(player.find('td',{"data-stat": "ft_pct"}))
            game_players['orb'] = get_text(player.find('td',{"data-stat": "orb"}))
            game_players['drb'] = get_text(player.find('td',{"data-stat": "drb"}))
            game_players['trb'] = get_text(player.find('td',{"data-stat": "trb"}))
            game_players['ast'] = get_text(player.find('td',{"data-stat": "ast"}))
            game_players['stl'] = get_text(player.find('td',{"data-stat": "stl"}))
            game_players['blk'] = get_text(player.find('td',{"data-stat": "blk"}))
            game_players['tov'] = get_text(player.find('td',{"data-stat": "tov"}))
            game_players['pf'] = get_text(player.find('td',{"data-stat": "pf"}))
            game_players['pts'] = get_text(player.find('td',{"data-stat": "pts"}))
            game_players['plus_minus'] = get_text(player.find('td',{"data-stat": "plus_minus"}))
            game_players['player_stat_key'] = game_players['game_key'] + '|' + game_players['player_key'] + '|' + game_players['stat_period'] 
            if cnt <= 5:
                game_players['starter_flag'] = True 
            else:
                game_players['starter_flag'] = False
            game_players['load_datetime'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")  
            #print(game_players)
            player_game_data.append(game_players)
            cnt += 1

    return player_game_data
   
def get_text(stat):
    if stat is not None:
        if stat.text != "":
            txt = stat.text
        else:
            txt = None
    else:
        txt = None
    return txt

def  nba_basketballreference_scraper(request):
    #Get project ID where function is run 
    project_id = os.environ.get('GCP_PROJECT')
    ##########################################################################
    # Input Data Check
    ##########################################################################
    
    # If request has specific StartDate/EndDate use those
    # Otherwise, use the maximum game date in BigQuery as StartDate and Yesterday as EndDate

    try:
        request_json = request.get_json()
    except:
        request_json = request
    
    try:
        if request_json and 'StartDate' in request_json:  
            startDate = datetime.strptime(request_json['StartDate'], '%Y-%m-%d').date()            
        else:
            startDate = get_max_game_date()
        if request_json and 'EndDate' in request_json:  
            endDate = datetime.strptime(request_json['EndDate'], '%Y-%m-%d').date() 
        else:
            endDate = (datetime.now() + timedelta(days=-1)).date()
    except Exception as e:
        raise ValueError("Start & End dates must be in YYYY-MM-DD format") from e

    # Distinct list of Months between start and end date
    delta = endDate - startDate       # as timedelta

    if delta.days < 0:
        raise ValueError("Start Date can't be before End Date")
    
    ##########################################################################
    # Get Distinct Months for schedule to scrape
    ##########################################################################
    
    yearmonths = []
    for i in range(delta.days + 1):
        r = {}
        day = startDate + timedelta(days=i)
        r['monthname'] = day.strftime('%B').lower()
        if day.month > 9:
            r['year'] = day.year + 1
        else:
            r['year'] = day.year
        if r not in yearmonths: 
            yearmonths.append(r)
    #print(yearmonths)
    
    ##########################################################################
    # Scrape Schedule
    ##########################################################################
    player_game_rows_loaded = 0
    game_rows_loaded = 0
    
    try:
        schedule = []
        for v in yearmonths:        
            year = str(v['year'])
            month = v['monthname']
            ## the 2019-2020 season had games in October 2019 and 2020 requiring custom URL logic
            if month == 'october' and (year == '2020' or year == '2021'):
                url = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}-{v["year"] - 1}.html'
            else:
                url = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}.html'
            #print(url)
        
            html = requests.get(url)
            
            if html.ok:
                soup = BeautifulSoup(html.content, 'html.parser')  
            else:
                print(f'No data for {month} {year} because enountered error code {html.status_code}')
                continue

            rows = soup.find('table', id="schedule").find('tbody').find_all('tr')
            #print(rows)
            
            for row in rows:
                game_date_node = row.find('th',{"data-stat": "date_game"})
                if game_date_node is not None:

                    game_date = datetime.strptime(game_date_node.text, '%a, %b %d, %Y').date()
                    if game_date >= startDate and game_date <= endDate:
                        #cells = row.find_all(['td', 'th'])
                        r = {}
                        #r.setdefault(game_start_time, []).append(value)

                        v1 = row.find('th',{"data-stat": "date_game"})
                        #r[k1] = v1.text
                        r['game_date'] = datetime.strptime(v1.text, '%a, %b %d, %Y').strftime("%Y-%m-%d")
                        
                        v2 = row.find('td',{"data-stat": "game_start_time"})
                        r['game_start_time'] = v2.text if v2 else None
                        
                        v3 = row.find('td',{"data-stat": "visitor_team_name"})
                        r['visitor_team_name'] = v3.text
                        r['away_abbr'] = v3['csk'].split('.')[0]
                        
                        v4 = row.find('td',{"data-stat": "visitor_pts"})
                        r['visitor_pts'] = v4.text if v4 else None
                        
                        v5 = row.find('td',{"data-stat": "home_team_name"})
                        r['home_team_name'] = v5.text
                        r['home_abbr'] = v5['csk'].split('.')[0]
                        
                        v6 = row.find('td',{"data-stat": "home_pts"})
                        r['home_pts'] = v6.text if v6 else None
                        
                        v7 = row.find('td',{"data-stat": "box_score_text"}).find('a',href=True)
                        r['box_score_url'] = v7['href'] if v7 else None
                            
                        v8 = row.find('td',{"data-stat": "attendance"})
                        r['attendance'] = v8.text if v8 else None
                        
                        v9 = row.find('td',{"data-stat": "overtimes"})
                        r['overtimes'] = v9.text if v9 else None
                        
                        if r['game_start_time']:
                            v12 = r['away_abbr'] + r['game_date'].replace('-','') + r['home_abbr'] + r['game_start_time'].replace(':','')
                        else:
                            v12 = r['away_abbr'] + r['game_date'].replace('-','') + r['home_abbr']
                        r['game_key'] = v12 if v12 else None
                    
                        schedule.append(r)
            #print(schedule)            
        
            ##########################################################################
            # Scrape Games in Schedule
            ##########################################################################
            games_data = []
            player_game_data = []

            for game in schedule:
                if 'box_score_url' in game and game['box_score_url'] != "" and game['box_score_url'] is not None:


                    url = "https://www.basketball-reference.com" + game['box_score_url']

                    #print(url)
                    r = requests.get(url)
 
                    soup = BeautifulSoup(str(r.content).replace("<!--","").replace('-->',''), 'html.parser')

                    ##############################################
                    # Line Score
                    rows = soup.find('table', id="line_score").find_all('tr')

                    # Away Line Score
                    r_num = 1
                    for away in rows[2].find_all('td'):
                        test_strong = away.find('strong') # Strong represents the total score ... ignore
                        if test_strong is None and r_num < 7:
                            k='a_g' + str(r_num) + '_score'
                            game[k] = away.text if away.text != "" else None
                        r_num+=1

                    # Home Line Score
                    r_num = 1
                    for home in rows[3].find_all('td'):
                        test_strong = home.find('strong') # Strong represents the total score ... ignore
                        if test_strong is None and r_num < 7:
                            k='h_g' + str(r_num) + '_score'
                            game[k] = home.text if home.text != "" else None
                        r_num+=1      

                    ##############################################
                    # Four Facts
                    rows = soup.find('table', id="four_factors").find_all('tr')

                    # Away Four Factors
                    game['a_ff_pace'] = rows[2].find('td',{"data-stat": "pace"}).text
                    game['a_ff_efg_pct'] = rows[2].find('td',{"data-stat": "efg_pct"}).text
                    game['a_ff_tov_pct'] = rows[2].find('td',{"data-stat": "tov_pct"}).text
                    game['a_ff_orb_pct'] = rows[2].find('td',{"data-stat": "orb_pct"}).text
                    game['a_ff_ft_rate'] = rows[2].find('td',{"data-stat": "ft_rate"}).text
                    game['a_ff_off_rtg'] = rows[2].find('td',{"data-stat": "off_rtg"}).text

                    # Home Four Factors
                    game['h_ff_pace'] = rows[3].find('td',{"data-stat": "pace"}).text
                    game['h_ff_efg_pct'] = rows[3].find('td',{"data-stat": "efg_pct"}).text
                    game['h_ff_tov_pct'] = rows[3].find('td',{"data-stat": "tov_pct"}).text
                    game['h_ff_orb_pct'] = rows[3].find('td',{"data-stat": "orb_pct"}).text
                    game['h_ff_ft_rate'] = rows[3].find('td',{"data-stat": "ft_rate"}).text
                    game['h_ff_off_rtg'] = rows[3].find('td',{"data-stat": "off_rtg"}).text
                    game['load_datetime'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")        

                    #now = datetime.now() # current date and time
                    #now.strftime("%m/%d/%Y, %H:%M:%S")


                    #player_game_data = []
                    game_date = game['game_date']

                    ##############################################
                    # Game Box - Home
                    stat_type = "game"
                    h_or_a = "h"
                    team_abbrev = game['home_abbr']
                    id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    ##############################################
                    # Game Box - Away
                    stat_type = "game"
                    h_or_a = "a"
                    team_abbrev = game['away_abbr']
                    id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q1 Box - Home
                    # stat_type = "q1"
                    # h_or_a = "h"
                    # team_abbrev = game['home_abbr']
                    # id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q1 Box - Away
                    # stat_type = "q1"
                    # h_or_a = "a"
                    # team_abbrev = game['away_abbr']
                    # id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q2 Box - Home
                    # stat_type = "q2"
                    # h_or_a = "h"
                    # team_abbrev = game['home_abbr']
                    # id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q2 Box - Away
                    # stat_type = "q2"
                    # h_or_a = "a"
                    # team_abbrev = game['away_abbr']
                    # id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q3 Box - Home
                    # stat_type = "q3"
                    # h_or_a = "h"
                    # team_abbrev = game['home_abbr']
                    # id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q3 Box - Away
                    # stat_type = "q3"
                    # h_or_a = "a"
                    # team_abbrev = game['away_abbr']
                    # id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q4 Box - Home
                    # stat_type = "q4"
                    # h_or_a = "h"
                    # team_abbrev = game['home_abbr']
                    # id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    # ##############################################
                    # # Q4 Box - Away
                    # stat_type = "q4"
                    # h_or_a = "a"
                    # team_abbrev = game['away_abbr']
                    # id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    # player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    games_data.append(game)


            ##########################################################################
            # Check for empty game data
            ##########################################################################
            # Continue to next month if there were no games in the month starting at the start date
            if not games_data:
                continue

            ##########################################################################
            # Save to BigQuery
            ##########################################################################

            # print(player_game_data)
            # print(games_data)
            # Create new bigquery client each loop
            client = bigquery.Client(project=project_id)
            
            print(f'Loading data for {month} {year}')
 
            #Publish game data
            try:
                pandas_games_data = pd.DataFrame(games_data)
                pandas_games_data['game_date'] = pandas_games_data['game_date'].astype('datetime64[ns]').dt.date
                pandas_games_data['load_datetime'] = pandas_games_data['load_datetime'].astype('datetime64[ns]')
                job_config = bigquery.LoadJobConfig()
                job_config.autodetect='False'
                job_config.create_disposition = 'CREATE_IF_NEEDED'
                job_config.write_disposition = 'WRITE_APPEND'
                ## Set schema for specific columns where more information is needed (e.g. not NULLABLE or specific date/time)
                job_config.schema = [
                    bigquery.SchemaField('game_key','STRING', 'REQUIRED'),
                    bigquery.SchemaField('game_date','DATE', 'REQUIRED'),
                    bigquery.SchemaField('home_team_name','STRING', 'REQUIRED'),
                    bigquery.SchemaField('home_abbr','STRING', 'REQUIRED'),
                    bigquery.SchemaField('visitor_team_name','STRING', 'REQUIRED'),
                    bigquery.SchemaField('away_abbr','STRING', 'REQUIRED'),
                    bigquery.SchemaField('load_datetime','TIMESTAMP'),
                    bigquery.SchemaField('game_start_time','STRING')
                ]
                job_config.time_partitioning = bigquery.TimePartitioning(
                    type_=bigquery.TimePartitioningType.DAY,
                    field="game_date")
                job_game = client.load_table_from_dataframe(pandas_games_data, 'nba.raw_basketballreference_game', job_config=job_config)
                game_result = job_game.result()
                game_message = (
                    f'Job ID: {game_result.job_id} '
                    f'was started {game_result.started} '
                    f'and ended {game_result.ended} '
                    f'loading {game_result.output_rows} row(s) '
                    f'to {game_result.destination}')
                print(game_message)
                game_rows_loaded = game_rows_loaded + game_result.output_rows
            except Exception as e:
                raise ValueError("Game data failed to load. See error and do not load player data") from e

            #Publish player game data
            pandas_player_game_data = pd.DataFrame(player_game_data)
            pandas_player_game_data['game_date'] = pandas_player_game_data['game_date'].astype('datetime64[ns]').dt.date
            pandas_player_game_data['load_datetime'] = pandas_player_game_data['load_datetime'].astype('datetime64[ns]')
            job_config = bigquery.LoadJobConfig()
            job_config.autodetect='False'
            job_config.create_disposition = 'CREATE_IF_NEEDED'
            job_config.write_disposition = 'WRITE_APPEND'
             ## Set schema for specific columns where more information is needed (e.g. not NULLABLE or specific date/time)
            job_config.schema = [
                bigquery.SchemaField('player_stat_key','STRING', 'REQUIRED'),
                bigquery.SchemaField('game_date','DATE'),
                bigquery.SchemaField('load_datetime','TIMESTAMP'),
                bigquery.SchemaField('starter_flag','BOOL')
            ]
            job_config.time_partitioning = bigquery.TimePartitioning(
                type_=bigquery.TimePartitioningType.DAY,
                field="game_date")
            job_player = client.load_table_from_dataframe(pandas_player_game_data, 'nba.raw_basketballreference_playerbox', job_config=job_config)
            player_result = job_player.result()
            player_message = (
                f'Job ID: {player_result.job_id} '
                f'was started {player_result.started} '
                f'and ended {player_result.ended} '
                f'loading {player_result.output_rows} row(s) '
                f'to {player_result.destination}')
            print(player_message)
            player_game_rows_loaded = player_game_rows_loaded + player_result.output_rows



    except Exception as e: 
        raise ValueError("Load Job Failed - Check error log for specific details") from e

    return f'Successfully loaded {player_game_rows_loaded} row(s) to raw_basketballreference_playerbox and {game_rows_loaded} to raw_basketballreference_game'

# %%
request = {'StartDate':'1999-11-01', 'EndDate':'2015-07-01'}

# %%
startDate = datetime.strptime(request['StartDate'], '%Y-%m-%d').date()

# %%
endDate = ''

# %%
#Uncomment top row to load up until current time. Use bottom row if setting a manual end date
#endDate_max = (datetime.now() + timedelta(days=-1)).date() 
endDate_max = datetime.strptime(request['EndDate'], '%Y-%m-%d').date()

# %%
while endDate != endDate_max:
    year, month= divmod(startDate.month+1, 12)
    if month == 0: 
          month = 12
          year = year -1
    endDate = date(startDate.year + year, month, 1) + timedelta(days=-1)
    if endDate >= endDate_max:
        endDate = endDate_max
    endDateformat = endDate.strftime('%Y-%m-%d')
    startDateformat = startDate.strftime('%Y-%m-%d')
    data = {"StartDate":startDateformat,"EndDate":endDateformat}
    print(data)
    response = nba_basketballreference_scraper(data)
    print(response)
    year, month= divmod(startDate.month+1, 12)
    if month == 0: 
          month = 12
          year = year -1
    startDate = date(startDate.year + year, month, 1)
# Out:
# {'StartDate': '1999-11-01', 'EndDate': '1999-11-30'}
# Loading data for november 2000
# Job ID: c0b50193-fb23-439a-86bc-489642a6df5e was started 2021-02-27 19:29:43.541000+00:00 and ended 2021-02-27 19:29:45.362000+00:00 loading 209 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: d47e0ffe-231d-4fc2-bce1-668d83719be4 was started 2021-02-27 19:29:47.104000+00:00 and ended 2021-02-27 19:29:48.986000+00:00 loading 4994 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4994 row(s) to raw_basketballreference_playerbox and 209 to raw_basketballreference_game
# {'StartDate': '1999-12-01', 'EndDate': '1999-12-31'}
# Loading data for december 2000
# Job ID: a01e524e-764d-49b0-a486-43da4b39ef46 was started 2021-02-27 19:32:20.558000+00:00 and ended 2021-02-27 19:32:22.344000+00:00 loading 213 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: b6c9c3ce-bbd8-4998-82b3-c492a0a0495a was started 2021-02-27 19:32:25.865000+00:00 and ended 2021-02-27 19:32:27.753000+00:00 loading 5078 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5078 row(s) to raw_basketballreference_playerbox and 213 to raw_basketballreference_game
# {'StartDate': '2000-01-01', 'EndDate': '2000-01-31'}
# Loading data for january 2000
# Job ID: cb868b3f-4a77-49fe-979c-310ce069caca was started 2021-02-27 19:34:48.273000+00:00 and ended 2021-02-27 19:34:50.038000+00:00 loading 204 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: ff5908bc-7d6d-42a9-b9b0-d43261c1341c was started 2021-02-27 19:34:52.474000+00:00 and ended 2021-02-27 19:34:54.490000+00:00 loading 4862 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4862 row(s) to raw_basketballreference_playerbox and 204 to raw_basketballreference_game
# {'StartDate': '2000-02-01', 'EndDate': '2000-02-29'}
# Loading data for february 2000
# Job ID: 0ffbe5a9-7d69-45f1-87a0-2d2c7e65591a was started 2021-02-27 19:36:59.117000+00:00 and ended 2021-02-27 19:37:00.961000+00:00 loading 188 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: c0a9ead9-540e-4119-ab7b-8e69076dbb55 was started 2021-02-27 19:37:03.310000+00:00 and ended 2021-02-27 19:37:05.094000+00:00 loading 4474 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4474 row(s) to raw_basketballreference_playerbox and 188 to raw_basketballreference_game
# {'StartDate': '2000-03-01', 'EndDate': '2000-03-31'}
# Loading data for march 2000
# Job ID: c9013ae4-cf9b-447c-a4d1-91e80ebf128f was started 2021-02-27 19:39:50.881000+00:00 and ended 2021-02-27 19:39:52.771000+00:00 loading 227 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 33c44ff4-c17c-4776-bbc3-feea1fe0bab9 was started 2021-02-27 19:39:55.385000+00:00 and ended 2021-02-27 19:39:57.334000+00:00 loading 5428 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5428 row(s) to raw_basketballreference_playerbox and 227 to raw_basketballreference_game
# {'StartDate': '2000-04-01', 'EndDate': '2000-04-30'}
# Loading data for april 2000
# Job ID: ab413c52-ff3e-4e8d-bf80-7901c9bb8c40 was started 2021-02-27 19:42:35.554000+00:00 and ended 2021-02-27 19:42:37.504000+00:00 loading 172 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: a15acae1-1bb9-4cac-9c0e-870411984a54 was started 2021-02-27 19:42:39.511000+00:00 and ended 2021-02-27 19:42:41.518000+00:00 loading 4136 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4136 row(s) to raw_basketballreference_playerbox and 172 to raw_basketballreference_game
# {'StartDate': '2000-05-01', 'EndDate': '2000-05-31'}
# Loading data for may 2000
# Job ID: c51e4168-b796-4ac1-b6b3-4bd1c860be1a was started 2021-02-27 19:43:22.878000+00:00 and ended 2021-02-27 19:43:24.611000+00:00 loading 42 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 70e6bf2b-57c8-4851-991d-a192571f549a was started 2021-02-27 19:43:25.475000+00:00 and ended 2021-02-27 19:43:27.278000+00:00 loading 1008 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 1008 row(s) to raw_basketballreference_playerbox and 42 to raw_basketballreference_game
# {'StartDate': '2000-06-01', 'EndDate': '2000-06-30'}
# Loading data for june 2000
# Job ID: 1b9f61cd-766f-4005-b859-0ce5e3de54d5 was started 2021-02-27 19:43:38.932000+00:00 and ended 2021-02-27 19:43:40.475000+00:00 loading 9 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: b557c057-ea10-47cc-a189-2aa0a925a7b4 was started 2021-02-27 19:43:44.611000+00:00 and ended 2021-02-27 19:43:46.242000+00:00 loading 216 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 216 row(s) to raw_basketballreference_playerbox and 9 to raw_basketballreference_game
# {'StartDate': '2000-07-01', 'EndDate': '2000-07-31'}
# No data for july 2000 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2000-08-01', 'EndDate': '2000-08-31'}
# No data for august 2000 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2000-09-01', 'EndDate': '2000-09-30'}
# No data for september 2000 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2000-10-01', 'EndDate': '2000-10-31'}
# Loading data for october 2001
# Job ID: 1fb469f8-84e0-4519-8a65-9cc88d48ff5c was started 2021-02-27 19:44:03.803000+00:00 and ended 2021-02-27 19:44:05.259000+00:00 loading 13 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 6bd69445-112f-4c87-a6f8-61003b99bd78 was started 2021-02-27 19:44:09.018000+00:00 and ended 2021-02-27 19:44:10.404000+00:00 loading 311 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 311 row(s) to raw_basketballreference_playerbox and 13 to raw_basketballreference_game
# {'StartDate': '2000-11-01', 'EndDate': '2000-11-30'}
# Loading data for november 2001
# Job ID: a960b477-6ba1-4531-922b-c42b9dc6557a was started 2021-02-27 19:47:22.182000+00:00 and ended 2021-02-27 19:47:24.273000+00:00 loading 209 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 79a9912a-f682-46b7-8d90-27b5062d7107 was started 2021-02-27 19:47:25.605000+00:00 and ended 2021-02-27 19:47:27.621000+00:00 loading 4995 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4995 row(s) to raw_basketballreference_playerbox and 209 to raw_basketballreference_game
# {'StartDate': '2000-12-01', 'EndDate': '2000-12-31'}
# Loading data for december 2001
# Job ID: 0abbfa52-9b0b-402c-87d0-5a576b107201 was started 2021-02-27 19:50:33.005000+00:00 and ended 2021-02-27 19:50:34.892000+00:00 loading 217 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: c3e51849-e353-4715-a1fd-948f165b46cc was started 2021-02-27 19:50:37.188000+00:00 and ended 2021-02-27 19:50:39.039000+00:00 loading 5190 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5190 row(s) to raw_basketballreference_playerbox and 217 to raw_basketballreference_game
# {'StartDate': '2001-01-01', 'EndDate': '2001-01-31'}
# Loading data for january 2001
# Job ID: 53e7994c-05a6-46df-9fd1-22b5a4d85f05 was started 2021-02-27 19:53:51.868000+00:00 and ended 2021-02-27 19:53:53.661000+00:00 loading 214 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: c9221a58-865e-4b89-b792-f4e9c423acd9 was started 2021-02-27 19:53:56.154000+00:00 and ended 2021-02-27 19:53:58.100000+00:00 loading 5113 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5113 row(s) to raw_basketballreference_playerbox and 214 to raw_basketballreference_game
# {'StartDate': '2001-02-01', 'EndDate': '2001-02-28'}
# Loading data for february 2001
# Job ID: 79887aeb-661c-4345-8ea0-f4ddd637e1b3 was started 2021-02-27 19:56:21.017000+00:00 and ended 2021-02-27 19:56:22.720000+00:00 loading 178 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: f248bb82-ba22-47f1-adfb-13a426f928c8 was started 2021-02-27 19:56:25.958000+00:00 and ended 2021-02-27 19:56:28.091000+00:00 loading 4260 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4260 row(s) to raw_basketballreference_playerbox and 178 to raw_basketballreference_game
# {'StartDate': '2001-03-01', 'EndDate': '2001-03-31'}
# Loading data for march 2001
# Job ID: 8c59b669-8962-4f08-bb06-eb4e07e502cb was started 2021-02-27 19:58:31.106000+00:00 and ended 2021-02-27 19:58:33.634000+00:00 loading 221 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 9f1603a6-3c07-4634-b854-2c775d8aade5 was started 2021-02-27 19:58:37.795000+00:00 and ended 2021-02-27 19:58:39.851000+00:00 loading 5286 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5286 row(s) to raw_basketballreference_playerbox and 221 to raw_basketballreference_game
# {'StartDate': '2001-04-01', 'EndDate': '2001-04-30'}
# Loading data for april 2001
# Job ID: 022d2c3c-7ff9-4a7a-9301-05dcbd7ffb95 was started 2021-02-27 20:00:11.540000+00:00 and ended 2021-02-27 20:00:13.344000+00:00 loading 162 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 050759df-70ce-4d90-a20e-d5f7acbd1d87 was started 2021-02-27 20:00:15.067000+00:00 and ended 2021-02-27 20:00:16.900000+00:00 loading 3879 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 3879 row(s) to raw_basketballreference_playerbox and 162 to raw_basketballreference_game
# {'StartDate': '2001-05-01', 'EndDate': '2001-05-31'}
# Loading data for may 2001
# Job ID: 39fd3d09-044c-4119-8c09-8dbae7e02590 was started 2021-02-27 20:00:41.569000+00:00 and ended 2021-02-27 20:00:43.531000+00:00 loading 39 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 6a97dda6-0a1f-452e-a266-67b5b3315d3e was started 2021-02-27 20:00:46.194000+00:00 and ended 2021-02-27 20:00:47.969000+00:00 loading 935 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 935 row(s) to raw_basketballreference_playerbox and 39 to raw_basketballreference_game
# {'StartDate': '2001-06-01', 'EndDate': '2001-06-30'}
# Loading data for june 2001
# Job ID: b4d125d6-beed-40a2-901d-8e7ec6c14ccf was started 2021-02-27 20:00:56.205000+00:00 and ended 2021-02-27 20:00:57.881000+00:00 loading 7 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 70dc6b4b-04ca-438d-8a77-8f46c6b06d1f was started 2021-02-27 20:00:59.891000+00:00 and ended 2021-02-27 20:01:01.562000+00:00 loading 168 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 168 row(s) to raw_basketballreference_playerbox and 7 to raw_basketballreference_game
# {'StartDate': '2001-07-01', 'EndDate': '2001-07-31'}
# No data for july 2001 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2001-08-01', 'EndDate': '2001-08-31'}
# No data for august 2001 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2001-09-01', 'EndDate': '2001-09-30'}
# No data for september 2001 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2001-10-01', 'EndDate': '2001-10-31'}
# Loading data for october 2002
# Job ID: 46a6cdc6-d6cd-44f7-8730-56412483f933 was started 2021-02-27 20:01:16.019000+00:00 and ended 2021-02-27 20:01:17.705000+00:00 loading 17 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 0d1e7c2e-bbac-49b5-a6bb-c981b30cbb38 was started 2021-02-27 20:01:21.417000+00:00 and ended 2021-02-27 20:01:23.053000+00:00 loading 408 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 408 row(s) to raw_basketballreference_playerbox and 17 to raw_basketballreference_game
# {'StartDate': '2001-11-01', 'EndDate': '2001-11-30'}
# Loading data for november 2002
# Job ID: 14167968-aefd-4b68-b092-e40e21d4c6de was started 2021-02-27 20:03:37.492000+00:00 and ended 2021-02-27 20:03:39.449000+00:00 loading 208 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 4b39b6cc-80e6-4f02-bdf8-5aef0a2816c9 was started 2021-02-27 20:03:48.042000+00:00 and ended 2021-02-27 20:03:50.005000+00:00 loading 4964 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4964 row(s) to raw_basketballreference_playerbox and 208 to raw_basketballreference_game
# {'StartDate': '2001-12-01', 'EndDate': '2001-12-31'}
# Loading data for december 2002
# Job ID: 54904daf-247b-48c7-9343-0ce472a2c658 was started 2021-02-27 20:05:47.194000+00:00 and ended 2021-02-27 20:05:48.976000+00:00 loading 207 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: ca0a235f-725f-4b0b-b2a5-95b0b9f4991d was started 2021-02-27 20:05:51.861000+00:00 and ended 2021-02-27 20:05:53.733000+00:00 loading 4947 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4947 row(s) to raw_basketballreference_playerbox and 207 to raw_basketballreference_game
# {'StartDate': '2002-01-01', 'EndDate': '2002-01-31'}
# Loading data for january 2002
# Job ID: 2a660851-4daf-41e0-94bf-309250302b79 was started 2021-02-27 20:07:50.785000+00:00 and ended 2021-02-27 20:07:52.676000+00:00 loading 215 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 16e4a1ab-5fd1-4d13-b056-87d6fa9fbb9a was started 2021-02-27 20:07:55.021000+00:00 and ended 2021-02-27 20:07:57.205000+00:00 loading 5127 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5127 row(s) to raw_basketballreference_playerbox and 215 to raw_basketballreference_game
# {'StartDate': '2002-02-01', 'EndDate': '2002-02-28'}
# Loading data for february 2002
# Job ID: eb259d4f-4f7f-4b24-a041-7e83fe707ea3 was started 2021-02-27 20:09:35.252000+00:00 and ended 2021-02-27 20:09:37.127000+00:00 loading 174 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: b2cbf97f-86ce-4590-9613-820918cb54f3 was started 2021-02-27 20:09:41.238000+00:00 and ended 2021-02-27 20:09:43.109000+00:00 loading 4148 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4148 row(s) to raw_basketballreference_playerbox and 174 to raw_basketballreference_game
# {'StartDate': '2002-03-01', 'EndDate': '2002-03-31'}
# Loading data for march 2002
# Job ID: 0976c084-9a6e-40d6-83a5-cb94e178cdb9 was started 2021-02-27 20:11:56.596000+00:00 and ended 2021-02-27 20:11:58.597000+00:00 loading 235 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: ddc93396-0f10-4cab-a105-ced2a96ebf18 was started 2021-02-27 20:12:01.186000+00:00 and ended 2021-02-27 20:12:03.386000+00:00 loading 5627 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5627 row(s) to raw_basketballreference_playerbox and 235 to raw_basketballreference_game
# {'StartDate': '2002-04-01', 'EndDate': '2002-04-30'}
# Loading data for april 2002
# Job ID: da67fd96-5192-416f-a4f2-dc864798547e was started 2021-02-27 20:13:58.011000+00:00 and ended 2021-02-27 20:14:00.123000+00:00 loading 161 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 2ef4dadf-5731-4ae5-8e9b-9015830b925f was started 2021-02-27 20:14:04.797000+00:00 and ended 2021-02-27 20:14:07.373000+00:00 loading 3870 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 3870 row(s) to raw_basketballreference_playerbox and 161 to raw_basketballreference_game
# {'StartDate': '2002-05-01', 'EndDate': '2002-05-31'}
# Loading data for may 2002
# Job ID: 95111b99-c087-4dcd-b789-381c2e8f014b was started 2021-02-27 20:14:30.693000+00:00 and ended 2021-02-27 20:14:32.406000+00:00 loading 38 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 7c18533a-ed9f-4307-8e59-40b5f6346e52 was started 2021-02-27 20:14:36.366000+00:00 and ended 2021-02-27 20:14:39.366000+00:00 loading 912 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 912 row(s) to raw_basketballreference_playerbox and 38 to raw_basketballreference_game
# {'StartDate': '2002-06-01', 'EndDate': '2002-06-30'}
# Loading data for june 2002
# Job ID: 0e61cba3-6612-43cd-9c16-b67798b52f58 was started 2021-02-27 20:14:46.360000+00:00 and ended 2021-02-27 20:14:47.981000+00:00 loading 5 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 04a28645-ce53-4109-b657-4ce3d86b75ce was started 2021-02-27 20:14:49.993000+00:00 and ended 2021-02-27 20:14:51.529000+00:00 loading 120 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 120 row(s) to raw_basketballreference_playerbox and 5 to raw_basketballreference_game
# {'StartDate': '2002-07-01', 'EndDate': '2002-07-31'}
# No data for july 2002 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2002-08-01', 'EndDate': '2002-08-31'}
# No data for august 2002 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2002-09-01', 'EndDate': '2002-09-30'}
# No data for september 2002 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2002-10-01', 'EndDate': '2002-10-31'}
# Loading data for october 2003
# Job ID: e193e33f-fc8f-4bba-bcc0-29715743f140 was started 2021-02-27 20:15:06.974000+00:00 and ended 2021-02-27 20:15:08.512000+00:00 loading 20 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: ad797e67-7840-44df-9cad-71488cda1013 was started 2021-02-27 20:15:09.825000+00:00 and ended 2021-02-27 20:15:11.293000+00:00 loading 475 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 475 row(s) to raw_basketballreference_playerbox and 20 to raw_basketballreference_game
# {'StartDate': '2002-11-01', 'EndDate': '2002-11-30'}
# Loading data for november 2003
# Job ID: c12374f9-6b51-4aed-962e-57a34f404bb4 was started 2021-02-27 20:17:11.225000+00:00 and ended 2021-02-27 20:17:13.549000+00:00 loading 217 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 1cb6d35a-4b3b-442d-98b7-0f0a239fd534 was started 2021-02-27 20:17:21.640000+00:00 and ended 2021-02-27 20:17:24.189000+00:00 loading 5214 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5214 row(s) to raw_basketballreference_playerbox and 217 to raw_basketballreference_game
# {'StartDate': '2002-12-01', 'EndDate': '2002-12-31'}
# Loading data for december 2003
# Job ID: 29fe89d7-bd7e-4d08-ab31-b0fb23265eac was started 2021-02-27 20:19:28.728000+00:00 and ended 2021-02-27 20:19:30.572000+00:00 loading 211 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 2a3debb5-0e4f-419f-acfe-d8ba920c4a07 was started 2021-02-27 20:19:34.331000+00:00 and ended 2021-02-27 20:19:36.309000+00:00 loading 5074 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5074 row(s) to raw_basketballreference_playerbox and 211 to raw_basketballreference_game
# {'StartDate': '2003-01-01', 'EndDate': '2003-01-31'}
# Loading data for january 2003
# Job ID: d77a7d37-84ba-415f-9918-b31b66022cf0 was started 2021-02-27 20:21:43.411000+00:00 and ended 2021-02-27 20:21:45.277000+00:00 loading 219 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: cec8778f-fb66-40dc-b5ff-b23c89f69b0a was started 2021-02-27 20:21:49.158000+00:00 and ended 2021-02-27 20:21:51.153000+00:00 loading 5289 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5289 row(s) to raw_basketballreference_playerbox and 219 to raw_basketballreference_game
# {'StartDate': '2003-02-01', 'EndDate': '2003-02-28'}
# Loading data for february 2003
# Job ID: 80dcf24a-d89d-46e7-a824-6d1f8e3e83d6 was started 2021-02-27 20:23:31.422000+00:00 and ended 2021-02-27 20:23:33.317000+00:00 loading 175 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: a4863106-d797-4409-9f51-13754cee8ac6 was started 2021-02-27 20:23:39.309000+00:00 and ended 2021-02-27 20:23:41.272000+00:00 loading 4211 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4211 row(s) to raw_basketballreference_playerbox and 175 to raw_basketballreference_game
# {'StartDate': '2003-03-01', 'EndDate': '2003-03-31'}
# Loading data for march 2003
# Job ID: 59b62cfa-b3c6-4232-8175-e778dbf1d99b was started 2021-02-27 20:25:52.109000+00:00 and ended 2021-02-27 20:25:54.045000+00:00 loading 224 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: d80d830e-1803-4d61-b3a2-4c4dfc449461 was started 2021-02-27 20:25:57.405000+00:00 and ended 2021-02-27 20:25:59.333000+00:00 loading 5379 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5379 row(s) to raw_basketballreference_playerbox and 224 to raw_basketballreference_game
# {'StartDate': '2003-04-01', 'EndDate': '2003-04-30'}
# Loading data for april 2003
# Job ID: 282b9057-f301-4074-a734-8bfa968c1e22 was started 2021-02-27 20:27:36.737000+00:00 and ended 2021-02-27 20:27:38.427000+00:00 loading 163 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: cf0c4a77-6a26-48a7-baf8-1a0adfa3be2d was started 2021-02-27 20:27:39.624000+00:00 and ended 2021-02-27 20:27:41.538000+00:00 loading 3926 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 3926 row(s) to raw_basketballreference_playerbox and 163 to raw_basketballreference_game
# {'StartDate': '2003-05-01', 'EndDate': '2003-05-31'}
# Loading data for may 2003
# Job ID: 06a1b17c-4171-45f0-b09b-ed35f5d5fb55 was started 2021-02-27 20:28:06.561000+00:00 and ended 2021-02-27 20:28:08.356000+00:00 loading 42 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 0b8d6964-5aa2-4f5a-b8f5-8476a245f6d6 was started 2021-02-27 20:28:09.771000+00:00 and ended 2021-02-27 20:28:11.494000+00:00 loading 1008 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 1008 row(s) to raw_basketballreference_playerbox and 42 to raw_basketballreference_game
# {'StartDate': '2003-06-01', 'EndDate': '2003-06-30'}
# Loading data for june 2003
# Job ID: 3cdfcb9f-82b3-4069-a06d-ccf7f382a604 was started 2021-02-27 20:28:18.927000+00:00 and ended 2021-02-27 20:28:20.318000+00:00 loading 6 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 89487df9-3bdf-4da6-9e4a-e199309c0437 was started 2021-02-27 20:28:21.061000+00:00 and ended 2021-02-27 20:28:22.574000+00:00 loading 144 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 144 row(s) to raw_basketballreference_playerbox and 6 to raw_basketballreference_game
# {'StartDate': '2003-07-01', 'EndDate': '2003-07-31'}
# No data for july 2003 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2003-08-01', 'EndDate': '2003-08-31'}
# No data for august 2003 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2003-09-01', 'EndDate': '2003-09-30'}
# No data for september 2003 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2003-10-01', 'EndDate': '2003-10-31'}
# Loading data for october 2004
# Job ID: 88f4385c-4d93-4b90-84c0-3f4d16506894 was started 2021-02-27 20:28:41.263000+00:00 and ended 2021-02-27 20:28:42.814000+00:00 loading 26 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 2ddca165-ee37-4696-86cc-c5f812814836 was started 2021-02-27 20:28:46.532000+00:00 and ended 2021-02-27 20:28:47.973000+00:00 loading 624 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 624 row(s) to raw_basketballreference_playerbox and 26 to raw_basketballreference_game
# {'StartDate': '2003-11-01', 'EndDate': '2003-11-30'}
# Loading data for november 2004
# Job ID: fb330539-b525-4ec2-a1d9-303eaa79300f was started 2021-02-27 20:30:41.418000+00:00 and ended 2021-02-27 20:30:43.178000+00:00 loading 208 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 06c2db7c-e800-4a70-9d7c-4461842d6001 was started 2021-02-27 20:30:47.575000+00:00 and ended 2021-02-27 20:30:49.620000+00:00 loading 4987 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4987 row(s) to raw_basketballreference_playerbox and 208 to raw_basketballreference_game
# {'StartDate': '2003-12-01', 'EndDate': '2003-12-31'}
# Loading data for december 2004
# Job ID: cd7e79ba-18b5-4df6-8207-7f747a01ccc1 was started 2021-02-27 20:32:51.949000+00:00 and ended 2021-02-27 20:32:53.865000+00:00 loading 216 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 4fb5ea73-594f-4823-9a76-18f0cc53ca45 was started 2021-02-27 20:32:57.439000+00:00 and ended 2021-02-27 20:32:59.461000+00:00 loading 5160 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5160 row(s) to raw_basketballreference_playerbox and 216 to raw_basketballreference_game
# {'StartDate': '2004-01-01', 'EndDate': '2004-01-31'}
# Loading data for january 2004
# Job ID: b85d1516-90d1-4283-86f6-40a7e2fa35ce was started 2021-02-27 20:35:05.285000+00:00 and ended 2021-02-27 20:35:07.059000+00:00 loading 227 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: e9ec7f5e-38f8-49cc-8ed1-05fddfb9d502 was started 2021-02-27 20:35:08.309000+00:00 and ended 2021-02-27 20:35:10.283000+00:00 loading 5394 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5394 row(s) to raw_basketballreference_playerbox and 227 to raw_basketballreference_game
# {'StartDate': '2004-02-01', 'EndDate': '2004-02-29'}
# Loading data for february 2004
# Job ID: 24434335-65b9-42eb-823e-be5288064d8c was started 2021-02-27 20:36:50.820000+00:00 and ended 2021-02-27 20:36:52.813000+00:00 loading 183 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: af270a02-1d43-4854-a52b-aae3ac77c1a3 was started 2021-02-27 20:36:59.387000+00:00 and ended 2021-02-27 20:37:01.434000+00:00 loading 4365 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 4365 row(s) to raw_basketballreference_playerbox and 183 to raw_basketballreference_game
# {'StartDate': '2004-03-01', 'EndDate': '2004-03-31'}
# Loading data for march 2004
# Job ID: ddcdabae-c98f-40bd-89e5-cee9376ead09 was started 2021-02-27 20:39:03.963000+00:00 and ended 2021-02-27 20:39:06.207000+00:00 loading 224 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: f7e6bafb-f63d-454c-99c0-d7a4a4f8c779 was started 2021-02-27 20:39:09.740000+00:00 and ended 2021-02-27 20:39:11.918000+00:00 loading 5347 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5347 row(s) to raw_basketballreference_playerbox and 224 to raw_basketballreference_game
# {'StartDate': '2004-04-01', 'EndDate': '2004-04-30'}
# Loading data for april 2004
# Job ID: 8f2f9147-0ea2-4bb6-9e72-0b4626a2510f was started 2021-02-27 20:40:27.402000+00:00 and ended 2021-02-27 20:40:29.146000+00:00 loading 142 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 56c9cb21-242f-4cd6-9c88-c1d0818d0789 was started 2021-02-27 20:40:34.622000+00:00 and ended 2021-02-27 20:40:36.447000+00:00 loading 3393 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 3393 row(s) to raw_basketballreference_playerbox and 142 to raw_basketballreference_game
# {'StartDate': '2004-05-01', 'EndDate': '2004-05-31'}
# Loading data for may 2004
# Job ID: 90bc20f5-8d70-46bc-9871-39e58f8508f7 was started 2021-02-27 20:40:58.043000+00:00 and ended 2021-02-27 20:40:59.898000+00:00 loading 39 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: a551561d-b121-438c-923c-cd60a0cb9b0d was started 2021-02-27 20:41:00.876000+00:00 and ended 2021-02-27 20:41:03.727000+00:00 loading 936 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 936 row(s) to raw_basketballreference_playerbox and 39 to raw_basketballreference_game
# {'StartDate': '2004-06-01', 'EndDate': '2004-06-30'}
# Loading data for june 2004
# Job ID: b992225d-4277-4b5a-ae3a-4aa1090ee152 was started 2021-02-27 20:41:12.057000+00:00 and ended 2021-02-27 20:41:13.785000+00:00 loading 6 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: 599d4ac2-935f-4676-8d6f-8b73423d48c5 was started 2021-02-27 20:41:14.927000+00:00 and ended 2021-02-27 20:41:16.463000+00:00 loading 144 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 144 row(s) to raw_basketballreference_playerbox and 6 to raw_basketballreference_game
# {'StartDate': '2004-07-01', 'EndDate': '2004-07-31'}
# No data for july 2004 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2004-08-01', 'EndDate': '2004-08-31'}
# No data for august 2004 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2004-09-01', 'EndDate': '2004-09-30'}
# No data for september 2004 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2004-10-01', 'EndDate': '2004-10-31'}
# No data for october 2005 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2004-11-01', 'EndDate': '2004-11-30'}
# Loading data for november 2005
# Job ID: 3cecd270-7d60-4c3b-94e7-3c71a4555357 was started 2021-02-27 20:43:08.496000+00:00 and ended 2021-02-27 20:43:10.429000+00:00 loading 210 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Job ID: c08a05a3-ca8f-46cb-9e1b-0077e202ee48 was started 2021-02-27 20:43:11.756000+00:00 and ended 2021-02-27 20:43:13.667000+00:00 loading 5035 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Successfully loaded 5035 row(s) to raw_basketballreference_playerbox and 210 to raw_basketballreference_game
# {'StartDate': '2004-12-01', 'EndDate': '2004-12-31'}
