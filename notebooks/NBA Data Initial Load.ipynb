# %%
import requests
from datetime import datetime, timedelta, date
from bs4 import BeautifulSoup
import pandas as pd
from google.cloud import bigquery
import pyarrow


project = 'nba-predictions-dev'

def get_max_game_date():
    client = bigquery.Client(project=project)
    
    QUERY = (
    "SELECT date_add(max(game_date), INTERVAL 1 day) as max_game_date FROM `nba.raw_basketballreference_game`"
    )
    query_job = client.query(QUERY)  # API request
    rows = query_job.result()  # Waits for query to finish
    
    for result in rows:
        load_date = result.max_game_date
    
    return load_date

def get_game_players(soup, player_game_data, id_string, game_key, stat_type, h_or_a, team_abbrev, game_date):
    rows = soup.find('table', id=id_string).find('tbody').find_all('tr')
    cnt = 1

    #print(str(rows))
    for player in rows:
        game_players = {}
        game_players['game_key'] = game_key
        game_players['game_date'] = game_date
        game_players['h_or_a'] = h_or_a
        game_players['team_abbrev'] = team_abbrev
        game_players['stat_period'] = stat_type
        game_players['player'] = player.find('th',{"data-stat": "player"}).text
        #print(game_players['player'])
        
        player_node = player.find('th',{"data-stat": "player"})
        
        # Ignore Header Line
        if game_players['player'] != 'Reserves' and player_node.has_attr('data-append-csv'):
        
            a = player.find('th',{"data-stat": "player"}).find('a',href=True)
            if a is not None:
                game_players['player_link'] = a['href']
            else:
                game_players['player_link'] = None
            
            game_players['player_key'] = player_node['data-append-csv']
            game_players['reason'] = get_text(player.find('td',{"data-stat": "reason"}))
            game_players['mp'] = get_text(player.find('td',{"data-stat": "mp"}))
            game_players['fg'] = get_text(player.find('td',{"data-stat": "fg"}))
            game_players['fga'] = get_text(player.find('td',{"data-stat": "fga"}))
            game_players['fg_pct'] = get_text(player.find('td',{"data-stat": "fg_pct"}))
            game_players['fg3'] = get_text(player.find('td',{"data-stat": "fg3"}))
            game_players['fg3a'] = get_text(player.find('td',{"data-stat": "fg3a"}))
            game_players['fg3_pct'] = get_text(player.find('td',{"data-stat": "fg3_pct"}))
            game_players['ft'] = get_text(player.find('td',{"data-stat": "ft"}))
            game_players['fta'] = get_text(player.find('td',{"data-stat": "fta"}))
            game_players['ft_pct'] = get_text(player.find('td',{"data-stat": "ft_pct"}))
            game_players['orb'] = get_text(player.find('td',{"data-stat": "orb"}))
            game_players['drb'] = get_text(player.find('td',{"data-stat": "drb"}))
            game_players['trb'] = get_text(player.find('td',{"data-stat": "trb"}))
            game_players['ast'] = get_text(player.find('td',{"data-stat": "ast"}))
            game_players['stl'] = get_text(player.find('td',{"data-stat": "stl"}))
            game_players['blk'] = get_text(player.find('td',{"data-stat": "blk"}))
            game_players['tov'] = get_text(player.find('td',{"data-stat": "tov"}))
            game_players['pf'] = get_text(player.find('td',{"data-stat": "pf"}))
            game_players['pts'] = get_text(player.find('td',{"data-stat": "pts"}))
            game_players['plus_minus'] = get_text(player.find('td',{"data-stat": "plus_minus"}))
            game_players['player_stat_key'] = game_players['game_key'] + '|' + game_players['player_key'] + '|' + game_players['stat_period'] 
            if cnt <= 5:
                game_players['starter_flag'] = True 
            else:
                game_players['starter_flag'] = False
            game_players['load_datetime'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")  
            #print(game_players)
            player_game_data.append(game_players)
            cnt += 1

    return player_game_data
   
def get_text(stat):
    if stat is not None:
        if stat.text != "":
            txt = stat.text
        else:
            txt = None
    else:
        txt = None
    return txt

def  nba_basketballreference_scraper(request):
   

    
    ##########################################################################
    # Input Data Check
    ##########################################################################
    
    try:
        request_json = request
        if request_json and 'StartDate' in request_json:  
            startDate = datetime.strptime(request_json['StartDate'], '%Y-%m-%d').date()            
        else:
            startDate = get_max_game_date()
        if request_json and 'EndDate' in request_json:  
            endDate = datetime.strptime(request_json['EndDate'], '%Y-%m-%d').date() 
        else:
            endDate = (datetime.now() + timedelta(days=-1)).date()
    except Exception as e:
        raise ValueError("Start & End dates must be in YYYY-MM-DD format") from e

    # Distinct list of Months between start and end date
    delta = endDate - startDate       # as timedelta

    if delta.days < 0:
        raise ValueError("Start Date can't be before End Date") 
    
    ##########################################################################
    # Get Distinct Months for schedule to scrape
    ##########################################################################
    
    yearmonths = []
    for i in range(delta.days + 1):
        r = {}
        day = startDate + timedelta(days=i)
        r['monthname'] = day.strftime('%B').lower()
        if day.month > 9:
            r['year'] = day.year + 1
        else:
            r['year'] = day.year
        if r not in yearmonths: 
            yearmonths.append(r)
    #print(yearmonths)
    
    ##########################################################################
    # Scrape Schedule
    ##########################################################################
    player_game_rows_loaded = 0
    game_rows_loaded = 0
    
    try:

        schedule = []
        for v in yearmonths:
            year = str(v['year'])
            month = v['monthname']
            url = 'https://www.basketball-reference.com/leagues/NBA_' + year + '_games-' + month + '.html'
            #print(url)
        
            html = requests.get(url)
            
            if html.ok:
                soup = BeautifulSoup(html.content, 'html.parser')  
            else:
                print(f'No data for {month} {year} because enountered error code {html.status_code}')
                continue

            rows = soup.find('table', id="schedule").find('tbody').find_all('tr')
            #print(rows)
            
            for row in rows:
                game_date_node = row.find('th',{"data-stat": "date_game"})
                if game_date_node is not None:

                    game_date = datetime.strptime(game_date_node.text, '%a, %b %d, %Y').date()
                    if game_date >= startDate and game_date <= endDate:
                        #cells = row.find_all(['td', 'th'])
                        r = {}
                        #r.setdefault(game_start_time, []).append(value)

                        v1 = row.find('th',{"data-stat": "date_game"})
                        #r[k1] = v1.text
                        r['game_date'] = datetime.strptime(v1.text, '%a, %b %d, %Y').strftime("%Y-%m-%d")
                        
                        v2 = row.find('td',{"data-stat": "game_start_time"})
                        r['game_start_time'] = v2.text if v2 else None
                        
                        v3 = row.find('td',{"data-stat": "visitor_team_name"})
                        r['visitor_team_name'] = v3.text
                        r['away_abbr'] = v3['csk'].split('.')[0]
                        
                        v4 = row.find('td',{"data-stat": "visitor_pts"})
                        r['visitor_pts'] = v4.text if v4 else None
                        
                        v5 = row.find('td',{"data-stat": "home_team_name"})
                        r['home_team_name'] = v5.text
                        r['home_abbr'] = v5['csk'].split('.')[0]
                        
                        v6 = row.find('td',{"data-stat": "home_pts"})
                        r['home_pts'] = v6.text if v6 else None
                        
                        v7 = row.find('td',{"data-stat": "box_score_text"}).find('a',href=True)
                        r['box_score_url'] = v7['href'] if v7 else None
                            
                        v8 = row.find('td',{"data-stat": "attendance"})
                        r['attendance'] = v8.text if v8 else None
                        
                        v9 = row.find('td',{"data-stat": "overtimes"})
                        r['overtimes'] = v9.text if v9 else None
                        
                        if r['game_start_time']:
                            v12 = r['away_abbr'] + r['game_date'].replace('-','') + r['home_abbr'] + r['game_start_time'].replace(':','')
                        else:
                            v12 = r['away_abbr'] + r['game_date'].replace('-','') + r['home_abbr']
                        r['game_key'] = v12 if v12 else None
                    
                        schedule.append(r)
            #print(schedule)            
        
            ##########################################################################
            # Scrape Games in Schedule
            ##########################################################################
            games_data = []
            player_game_data = []

            for game in schedule:
                if 'box_score_url' in game and game['box_score_url'] != "" and game['box_score_url'] is not None:


                    url = "https://www.basketball-reference.com" + game['box_score_url']

                    #print(url)
                    r = requests.get(url)
                    #print('here2')
                    soup = BeautifulSoup(str(r.content).replace("<!--","").replace('-->',''), 'html.parser')

                    ##############################################
                    # Line Score
                    rows = soup.find('table', id="line_score").find_all('tr')

                    # Away Line Score
                    r_num = 1
                    for away in rows[2].find_all('td'):
                        test_strong = away.find('strong') # Strong represents the total score ... ignore
                        if test_strong is None and r_num < 7:
                            k='a_g' + str(r_num) + '_score'
                            game[k] = away.text if away.text != "" else None
                        r_num+=1

                    # Home Line Score
                    r_num = 1
                    for home in rows[3].find_all('td'):
                        test_strong = home.find('strong') # Strong represents the total score ... ignore
                        if test_strong is None and r_num < 7:
                            k='h_g' + str(r_num) + '_score'
                            game[k] = home.text if home.text != "" else None
                        r_num+=1    

                    ##############################################
                    # Four Facts
                    rows = soup.find('table', id="four_factors").find_all('tr')

                    # Away Four Factors
                    game['a_ff_pace'] = rows[2].find('td',{"data-stat": "pace"}).text
                    game['a_ff_efg_pct'] = rows[2].find('td',{"data-stat": "efg_pct"}).text
                    game['a_ff_tov_pct'] = rows[2].find('td',{"data-stat": "tov_pct"}).text
                    game['a_ff_orb_pct'] = rows[2].find('td',{"data-stat": "orb_pct"}).text
                    game['a_ff_ft_rate'] = rows[2].find('td',{"data-stat": "ft_rate"}).text
                    game['a_ff_off_rtg'] = rows[2].find('td',{"data-stat": "off_rtg"}).text

                    # Home Four Factors
                    game['h_ff_pace'] = rows[3].find('td',{"data-stat": "pace"}).text
                    game['h_ff_efg_pct'] = rows[3].find('td',{"data-stat": "efg_pct"}).text
                    game['h_ff_tov_pct'] = rows[3].find('td',{"data-stat": "tov_pct"}).text
                    game['h_ff_orb_pct'] = rows[3].find('td',{"data-stat": "orb_pct"}).text
                    game['h_ff_ft_rate'] = rows[3].find('td',{"data-stat": "ft_rate"}).text
                    game['h_ff_off_rtg'] = rows[3].find('td',{"data-stat": "off_rtg"}).text
                    game['load_datetime'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")        

                    #now = datetime.now() # current date and time
                    #now.strftime("%m/%d/%Y, %H:%M:%S")


                    #player_game_data = []
                    game_date = game['game_date']

                    ##############################################
                    # Game Box - Home
                    #box-WAS-q1-basic
                    stat_type = "game"
                    h_or_a = "h"
                    team_abbrev = game['home_abbr']
                    id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
                    player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    ##############################################
                    # Game Box - Away
                    #box-WAS-q1-basic
                    stat_type = "game"
                    h_or_a = "a"
                    team_abbrev = game['away_abbr']
                    id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
                    player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

#                     ##############################################
#                     # Q1 Box - Home
#                     stat_type = "q1"
#                     h_or_a = "h"
#                     team_abbrev = game['home_abbr']
#                     id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
#                     player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

#                     ##############################################
#                     # Q1 Box - Away
#                     stat_type = "q1"
#                     h_or_a = "a"
#                     team_abbrev = game['away_abbr']
#                     id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
#                     player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

#                     ##############################################
#                     # Q2 Box - Home
#                     stat_type = "q2"
#                     h_or_a = "h"
#                     team_abbrev = game['home_abbr']
#                     id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
#                     player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

#                     ##############################################
#                     # Q2 Box - Away
#                     stat_type = "q2"
#                     h_or_a = "a"
#                     team_abbrev = game['away_abbr']
#                     id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
#                     player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

#                     ##############################################
#                     # Q3 Box - Home
#                     stat_type = "q3"
#                     h_or_a = "h"
#                     team_abbrev = game['home_abbr']
#                     id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
#                     player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

#                     ##############################################
#                     # Q3 Box - Away
#                     stat_type = "q3"
#                     h_or_a = "a"
#                     team_abbrev = game['away_abbr']
#                     id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
#                     player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

#                     ##############################################
#                     # Q4 Box - Home
#                     stat_type = "q4"
#                     h_or_a = "h"
#                     team_abbrev = game['home_abbr']
#                     id_string = "box-" + game['home_abbr'] + "-" + stat_type + "-basic"
#                     player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

#                     ##############################################
#                     # Q4 Box - Away
#                     stat_type = "q4"
#                     h_or_a = "a"
#                     team_abbrev = game['away_abbr']
#                     id_string = "box-" + game['away_abbr'] + "-" + stat_type + "-basic"
#                     player_game_data = get_game_players(soup, player_game_data, id_string, game['game_key'], stat_type, h_or_a, team_abbrev, game_date)

                    games_data.append(game)

            ##########################################################################
            # Check for empty game data
            ##########################################################################
            # Continue to next month if there were no games in the month starting at the start date
            if not games_data:
                continue                    
    
            ##########################################################################
            # Save to BigQuery
            ##########################################################################

            # print(player_game_data)
            # print(games_data)

            # Config
            client = bigquery.Client(project=project)
            print(f'Loading data for {month} {year}')
            
            #player game data
            pandas_player_game_data = pd.DataFrame(player_game_data)
            pandas_player_game_data['game_date'] = pandas_player_game_data['game_date'].astype('datetime64[ns]')
            pandas_player_game_data['load_datetime'] = pandas_player_game_data['load_datetime'].astype('datetime64[ns]')
            job_config = bigquery.LoadJobConfig()
            job_config.autodetect='True'
            job_config.create_disposition = 'CREATE_IF_NEEDED'
            job_config.write_disposition = 'WRITE_APPEND'
             ## Set schema for specific columns where more information is needed (e.g. not NULLABLE or specific date/time)
            job_config.schema = [
                bigquery.SchemaField('player_stat_key','STRING', 'REQUIRED'),
                bigquery.SchemaField('game_date','DATE'),
                bigquery.SchemaField('load_datetime','TIMESTAMP'),
                bigquery.SchemaField('starter_flag','BOOL')
            ]
            job_config.time_partitioning = bigquery.TimePartitioning(
                type_=bigquery.TimePartitioningType.DAY,
                field="game_date")
            job_player = client.load_table_from_dataframe(pandas_player_game_data, 'nba.raw_basketballreference_playerbox', job_config=job_config)
            player_result = job_player.result()
            player_message = (
                f'Job ID: {player_result.job_id} '
                f'was started {player_result.started} '
                f'and ended {player_result.ended} '
                f'loading {player_result.output_rows} row(s) '
                f'to {player_result.destination}')
            print(player_message)
            player_game_rows_loaded = player_game_rows_loaded + player_result.output_rows

            #game data
            pandas_games_data = pd.DataFrame(games_data)
            pandas_games_data['game_date'] = pandas_games_data['game_date'].astype('datetime64[ns]')
            pandas_games_data['load_datetime'] = pandas_games_data['load_datetime'].astype('datetime64[ns]')
            job_config = bigquery.LoadJobConfig()
            job_config.autodetect='True'
            job_config.create_disposition = 'CREATE_IF_NEEDED'
            job_config.write_disposition = 'WRITE_APPEND'
            ## Set schema for specific columns where more information is needed (e.g. not NULLABLE or specific date/time)
            job_config.schema = [
                bigquery.SchemaField('game_key','STRING', 'REQUIRED'),
                bigquery.SchemaField('game_date','STRING', 'REQUIRED'),
                bigquery.SchemaField('home_team_name','STRING', 'REQUIRED'),
                bigquery.SchemaField('home_abbr','STRING', 'REQUIRED'),
                bigquery.SchemaField('visitor_team_name','STRING', 'REQUIRED'),
                bigquery.SchemaField('away_abbr','STRING', 'REQUIRED'),
                bigquery.SchemaField('game_date','DATE'),
                bigquery.SchemaField('load_datetime','TIMESTAMP'),
            ]
            job_config.time_partitioning = bigquery.TimePartitioning(
                type_=bigquery.TimePartitioningType.DAY,
                field="game_date")
            job_game = client.load_table_from_dataframe(pandas_games_data, 'nba.raw_basketballreference_game', job_config=job_config)
            game_result = job_game.result()
            game_message = (
                f'Job ID: {game_result.job_id} '
                f'was started {game_result.started} '
                f'and ended {game_result.ended} '
                f'loading {game_result.output_rows} row(s) '
                f'to {game_result.destination}')
            print(game_message)
            game_rows_loaded = game_rows_loaded + game_result.output_rows

    except Exception as e: 
        raise ValueError("Load Job Failed - Check error log for specific details") from e
        
    return f'Successfully loaded {player_game_rows_loaded} row(s) to raw_basketballreference_playerbox and {game_rows_loaded} to raw_basketballreference_game'

# %%
request = {'StartDate':'2017-02-01'}

# %%
startDate = datetime.strptime(request['StartDate'], '%Y-%m-%d').date()

# %%
endDate = ''

# %%
endDate_max = (datetime.now() + timedelta(days=-1)).date()

# %%
while endDate != endDate_max:
    year, month= divmod(startDate.month+1, 12)
    if month == 0: 
          month = 12
          year = year -1
    endDate = date(startDate.year + year, month, 1) + timedelta(days=-1)
    if endDate >= endDate_max:
        endDate = endDate_max
    endDateformat = endDate.strftime('%Y-%m-%d')
    startDateformat = startDate.strftime('%Y-%m-%d')
    data = {"StartDate":startDateformat,"EndDate":endDateformat}
    print(data)
    response = nba_basketballreference_scraper(data)
    print(response)
    year, month= divmod(startDate.month+1, 12)
    if month == 0: 
          month = 12
          year = year -1
    startDate = date(startDate.year + year, month, 1)
# Out:
# {'StartDate': '2017-02-01', 'EndDate': '2017-02-28'}
# Loading data for february 2017
# Job ID: 447c8959-eea8-4109-95d2-c5210664c6d2 was started 2021-02-25 01:00:59.036000+00:00 and ended 2021-02-25 01:01:01.374000+00:00 loading 4199 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 5cfbd0f3-44b8-4f5d-8d72-83a58c87b75e was started 2021-02-25 01:01:03.251000+00:00 and ended 2021-02-25 01:01:06.110000+00:00 loading 165 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 4199 row(s) to raw_basketballreference_playerbox and 165 to raw_basketballreference_game
# {'StartDate': '2017-03-01', 'EndDate': '2017-03-31'}
# Loading data for march 2017
# Job ID: 0417086f-0b99-4eb0-a7d7-60b5be69b98c was started 2021-02-25 01:05:43.350000+00:00 and ended 2021-02-25 01:05:46.008000+00:00 loading 6161 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 0b09fdd9-e525-480f-b710-b6c3dfd9030a was started 2021-02-25 01:05:48.807000+00:00 and ended 2021-02-25 01:05:51.350000+00:00 loading 241 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 6161 row(s) to raw_basketballreference_playerbox and 241 to raw_basketballreference_game
# {'StartDate': '2017-04-01', 'EndDate': '2017-04-30'}
# Loading data for april 2017
# Job ID: 3c790dfc-674e-4c21-9cf5-b8f6698c8bb1 was started 2021-02-25 01:08:31.776000+00:00 and ended 2021-02-25 01:08:34.294000+00:00 loading 3587 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: e5d89c6e-ba6d-43ef-84b4-515d46fda0ff was started 2021-02-25 01:08:36.229000+00:00 and ended 2021-02-25 01:08:38.257000+00:00 loading 140 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 3587 row(s) to raw_basketballreference_playerbox and 140 to raw_basketballreference_game
# {'StartDate': '2017-05-01', 'EndDate': '2017-05-31'}
# Loading data for may 2017
# Job ID: 8650a7db-d33b-4b86-8eb6-d6d0c0894381 was started 2021-02-25 01:09:29.041000+00:00 and ended 2021-02-25 01:09:31.435000+00:00 loading 754 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: d2be923e-0498-47c5-833d-5c0dfa3bcac1 was started 2021-02-25 01:09:34.772000+00:00 and ended 2021-02-25 01:09:39.129000+00:00 loading 29 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 754 row(s) to raw_basketballreference_playerbox and 29 to raw_basketballreference_game
# {'StartDate': '2017-06-01', 'EndDate': '2017-06-30'}
# Loading data for june 2017
# Job ID: 47e07b3e-5a99-45d3-9047-0b971176b622 was started 2021-02-25 01:09:55.871000+00:00 and ended 2021-02-25 01:09:57.661000+00:00 loading 130 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 01207c7b-17d1-42ae-8396-4f69099dd50e was started 2021-02-25 01:10:01.492000+00:00 and ended 2021-02-25 01:10:03.520000+00:00 loading 5 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 130 row(s) to raw_basketballreference_playerbox and 5 to raw_basketballreference_game
# {'StartDate': '2017-07-01', 'EndDate': '2017-07-31'}
# No data for july 2017 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2017-08-01', 'EndDate': '2017-08-31'}
# No data for august 2017 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2017-09-01', 'EndDate': '2017-09-30'}
# No data for september 2017 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2017-10-01', 'EndDate': '2017-10-31'}
# Loading data for october 2018
# Job ID: 17275be9-ad15-4847-b53b-f1ce2dc3372d was started 2021-02-25 01:12:13.883000+00:00 and ended 2021-02-25 01:12:16.370000+00:00 loading 2672 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 84979829-4688-416a-9b21-8091930b583b was started 2021-02-25 01:12:17.544000+00:00 and ended 2021-02-25 01:12:19.565000+00:00 loading 104 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 2672 row(s) to raw_basketballreference_playerbox and 104 to raw_basketballreference_game
# {'StartDate': '2017-11-01', 'EndDate': '2017-11-30'}
# Loading data for november 2018
# Job ID: cc934add-462e-4fb1-b427-8feb21110caf was started 2021-02-25 01:16:16.720000+00:00 and ended 2021-02-25 01:16:19.338000+00:00 loading 5380 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: dd9eafb3-5f08-4ab6-ae3b-5ccbf1a9fe78 was started 2021-02-25 01:16:26.902000+00:00 and ended 2021-02-25 01:16:29.181000+00:00 loading 213 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 5380 row(s) to raw_basketballreference_playerbox and 213 to raw_basketballreference_game
# {'StartDate': '2017-12-01', 'EndDate': '2017-12-31'}
# Loading data for december 2018
# Job ID: 8a649a95-fa03-43e1-8323-16b0caa53f3e was started 2021-02-25 01:20:45.580000+00:00 and ended 2021-02-25 01:20:48.362000+00:00 loading 5707 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 90708814-57de-496a-90f8-0efe3eb3e97b was started 2021-02-25 01:20:50.835000+00:00 and ended 2021-02-25 01:20:53.035000+00:00 loading 227 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 5707 row(s) to raw_basketballreference_playerbox and 227 to raw_basketballreference_game
# {'StartDate': '2018-01-01', 'EndDate': '2018-01-31'}
# Loading data for january 2018
# Job ID: 2043dbd9-d5d9-48be-862e-c8e68c784832 was started 2021-02-25 01:24:57.761000+00:00 and ended 2021-02-25 01:25:00.355000+00:00 loading 5412 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 2a190cdf-1747-43d9-a722-2392324760df was started 2021-02-25 01:25:08.065000+00:00 and ended 2021-02-25 01:25:10.521000+00:00 loading 216 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 5412 row(s) to raw_basketballreference_playerbox and 216 to raw_basketballreference_game
# {'StartDate': '2018-02-01', 'EndDate': '2018-02-28'}
# Loading data for february 2018
# Job ID: ce16f055-49c7-4808-af18-1b3ddd369f2c was started 2021-02-25 01:28:16.473000+00:00 and ended 2021-02-25 01:28:18.938000+00:00 loading 3994 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 241a81a1-cb57-4ba8-8d90-e2c1266f2091 was started 2021-02-25 01:28:23.390000+00:00 and ended 2021-02-25 01:28:25.703000+00:00 loading 160 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 3994 row(s) to raw_basketballreference_playerbox and 160 to raw_basketballreference_game
# {'StartDate': '2018-03-01', 'EndDate': '2018-03-31'}
# Loading data for march 2018
# Job ID: 71135524-0072-4d9c-b872-4ea6f0df9a55 was started 2021-02-25 01:32:30.624000+00:00 and ended 2021-02-25 01:32:33.376000+00:00 loading 5595 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 060b8a63-cd58-4217-b59b-7ee3fa2715ec was started 2021-02-25 01:32:34.387000+00:00 and ended 2021-02-25 01:32:36.391000+00:00 loading 222 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 5595 row(s) to raw_basketballreference_playerbox and 222 to raw_basketballreference_game
# {'StartDate': '2018-04-01', 'EndDate': '2018-04-30'}
# Loading data for april 2018
# Job ID: 6c3ac946-f468-4a37-a340-a0e87ed63163 was started 2021-02-25 01:35:18.155000+00:00 and ended 2021-02-25 01:35:20.998000+00:00 loading 3454 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: f9ba67b7-cf51-4ce0-a748-e8dade941738 was started 2021-02-25 01:35:23.544000+00:00 and ended 2021-02-25 01:35:25.977000+00:00 loading 136 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 3454 row(s) to raw_basketballreference_playerbox and 136 to raw_basketballreference_game
# {'StartDate': '2018-05-01', 'EndDate': '2018-05-31'}
# Loading data for may 2018
# Job ID: ed7e61e8-3fd3-499f-b104-60cb054d7035 was started 2021-02-25 01:36:07.919000+00:00 and ended 2021-02-25 01:36:10.269000+00:00 loading 794 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: eb31b85b-ad12-41df-b8ee-2113c15fc761 was started 2021-02-25 01:36:11.558000+00:00 and ended 2021-02-25 01:36:14.161000+00:00 loading 31 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 794 row(s) to raw_basketballreference_playerbox and 31 to raw_basketballreference_game
# {'StartDate': '2018-06-01', 'EndDate': '2018-06-30'}
# Loading data for june 2018
# Job ID: 9bb93394-55c7-4ee8-8bd0-eae7a0cd634a was started 2021-02-25 01:36:30.594000+00:00 and ended 2021-02-25 01:36:32.526000+00:00 loading 78 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: f7d25b4b-e99d-43c1-ac91-78f9e661f793 was started 2021-02-25 01:36:36.055000+00:00 and ended 2021-02-25 01:36:37.945000+00:00 loading 3 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 78 row(s) to raw_basketballreference_playerbox and 3 to raw_basketballreference_game
# {'StartDate': '2018-07-01', 'EndDate': '2018-07-31'}
# No data for july 2018 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2018-08-01', 'EndDate': '2018-08-31'}
# No data for august 2018 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2018-09-01', 'EndDate': '2018-09-30'}
# No data for september 2018 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2018-10-01', 'EndDate': '2018-10-31'}
# Loading data for october 2019
# Job ID: 09ff24c2-b018-4438-bb46-0bf2d4e1a742 was started 2021-02-25 01:38:49.849000+00:00 and ended 2021-02-25 01:38:52.380000+00:00 loading 2802 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: ed53c9b0-f8a8-4ad9-b183-75704b4c3b50 was started 2021-02-25 01:38:55.511000+00:00 and ended 2021-02-25 01:38:57.638000+00:00 loading 110 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 2802 row(s) to raw_basketballreference_playerbox and 110 to raw_basketballreference_game
# {'StartDate': '2018-11-01', 'EndDate': '2018-11-30'}
# Loading data for november 2019
# Job ID: 73352236-ac68-45a4-9bca-946c370aa9a9 was started 2021-02-25 01:43:03.004000+00:00 and ended 2021-02-25 01:43:06.030000+00:00 loading 5482 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: c8f73ee5-3f18-4101-8222-b851ae7be05c was started 2021-02-25 01:43:10.331000+00:00 and ended 2021-02-25 01:43:12.584000+00:00 loading 219 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 5482 row(s) to raw_basketballreference_playerbox and 219 to raw_basketballreference_game
# {'StartDate': '2018-12-01', 'EndDate': '2018-12-31'}
# Loading data for december 2019
# Job ID: dd922e9d-5025-4c92-ab5d-ad57dc2dfa21 was started 2021-02-25 01:47:21.949000+00:00 and ended 2021-02-25 01:47:24.501000+00:00 loading 5465 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 2e88b84a-c372-4124-abb3-594bb2bd0436 was started 2021-02-25 01:47:25.819000+00:00 and ended 2021-02-25 01:47:28.113000+00:00 loading 219 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 5465 row(s) to raw_basketballreference_playerbox and 219 to raw_basketballreference_game
# {'StartDate': '2019-01-01', 'EndDate': '2019-01-31'}
# Loading data for january 2019
# Job ID: 604a86d4-a63a-4bc7-aaa0-11c228aa7a7f was started 2021-02-25 01:51:28.645000+00:00 and ended 2021-02-25 01:51:31.175000+00:00 loading 5511 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: fbb61224-9116-4c0f-982c-06cfa06b57d9 was started 2021-02-25 01:51:32.709000+00:00 and ended 2021-02-25 01:51:35.018000+00:00 loading 221 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 5511 row(s) to raw_basketballreference_playerbox and 221 to raw_basketballreference_game
# {'StartDate': '2019-02-01', 'EndDate': '2019-02-28'}
# Loading data for february 2019
# Job ID: 7027dc52-e3f9-42fe-a0f3-f97aa2a8e852 was started 2021-02-25 01:54:29.238000+00:00 and ended 2021-02-25 01:54:31.528000+00:00 loading 3918 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 24d9e7a1-b49d-4b37-a9b8-753311d59ef6 was started 2021-02-25 01:54:33.272000+00:00 and ended 2021-02-25 01:54:35.214000+00:00 loading 158 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 3918 row(s) to raw_basketballreference_playerbox and 158 to raw_basketballreference_game
# {'StartDate': '2019-03-01', 'EndDate': '2019-03-31'}
# Loading data for march 2019
# Job ID: fa609cce-84f6-4edc-96e4-acb5aaa8f324 was started 2021-02-25 01:58:58.034000+00:00 and ended 2021-02-25 01:59:00.404000+00:00 loading 5618 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 96040f44-1085-4220-b9cb-f39088a1f4a5 was started 2021-02-25 01:59:05.946000+00:00 and ended 2021-02-25 01:59:08.336000+00:00 loading 224 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 5618 row(s) to raw_basketballreference_playerbox and 224 to raw_basketballreference_game
# {'StartDate': '2019-04-01', 'EndDate': '2019-04-30'}
# Loading data for april 2019
# Job ID: cf862acc-0677-4d8c-b654-a248fbce9e22 was started 2021-02-25 02:01:37.785000+00:00 and ended 2021-02-25 02:01:40.550000+00:00 loading 3216 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: cf2e48b2-1e4f-4581-ab2a-6f506bb300af was started 2021-02-25 02:01:41.845000+00:00 and ended 2021-02-25 02:01:44.009000+00:00 loading 127 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 3216 row(s) to raw_basketballreference_playerbox and 127 to raw_basketballreference_game
# {'StartDate': '2019-05-01', 'EndDate': '2019-05-31'}
# Loading data for may 2019
# Job ID: e45aa9ba-c257-4086-acbe-c10d8b0764df was started 2021-02-25 02:02:21.359000+00:00 and ended 2021-02-25 02:02:24.140000+00:00 loading 751 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: a601c3ab-8bba-4ee5-b159-48381969aa84 was started 2021-02-25 02:02:25.233000+00:00 and ended 2021-02-25 02:02:27.694000+00:00 loading 29 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 751 row(s) to raw_basketballreference_playerbox and 29 to raw_basketballreference_game
# {'StartDate': '2019-06-01', 'EndDate': '2019-06-30'}
# Loading data for june 2019
# Job ID: 64a7c80c-c9b4-43ca-bcb5-879e17dbb3d9 was started 2021-02-25 02:02:41.189000+00:00 and ended 2021-02-25 02:02:43.064000+00:00 loading 130 row(s) to nba-predictions-dev.nba.raw_basketballreference_playerbox
# Job ID: 39cd998c-6249-4e2c-a0e6-6e300bb50d13 was started 2021-02-25 02:02:45.275000+00:00 and ended 2021-02-25 02:02:47.162000+00:00 loading 5 row(s) to nba-predictions-dev.nba.raw_basketballreference_game
# Successfully loaded 130 row(s) to raw_basketballreference_playerbox and 5 to raw_basketballreference_game
# {'StartDate': '2019-07-01', 'EndDate': '2019-07-31'}
# No data for july 2019 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2019-08-01', 'EndDate': '2019-08-31'}
# No data for august 2019 because enountered error code 404
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2019-09-01', 'EndDate': '2019-09-30'}
# Successfully loaded 0 row(s) to raw_basketballreference_playerbox and 0 to raw_basketballreference_game
# {'StartDate': '2019-10-01', 'EndDate': '2019-10-31'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-5d4778bdc515> in nba_basketballreference_scraper(request)
#     161
# --> 162             rows = soup.find('table', id="schedule").find('tbody').find_all('tr')
#     163             #print(rows)
#
# AttributeError: 'NoneType' object has no attribute 'find'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-606e7fb281ee> in <module>
#      11     data = {"StartDate":startDateformat,"EndDate":endDateformat}
#      12     print(data)
# ---> 13     response = nba_basketballreference_scraper(data)
#      14     print(response)
#      15     year, month= divmod(startDate.month+1, 12)
#
# <ipython-input-1-5d4778bdc515> in nba_basketballreference_scraper(request)
#     444
#     445     except Exception as e:
# --> 446         raise ValueError("Load Job Failed - Check error log for specific details") from e
#     447
#     448     return f'Successfully loaded {player_game_rows_loaded} row(s) to raw_basketballreference_playerbox and {game_rows_loaded} to raw_basketballreference_game'
#
# ValueError: Load Job Failed - Check error log for specific details
